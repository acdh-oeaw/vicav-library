# %% [markdown]
# # Script to automate the export and manipulation of the VICAV-library
#
# ## Import Package eTree to parse XML Files

# %%
import requests
import json
import logging
import os
import re
import xml
import xml.etree.ElementTree as ET
from lxml import isoschematron, etree
from urllib.parse import urlparse, parse_qs, urlencode
import asyncio
import aiohttp
# this module is needed to make asyncio.run work inside the notebook as well as in the generated python script
import nest_asyncio
from random import random
import saxonche
import itertools 
from datetime import datetime

nest_asyncio.apply()
logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
#logging.basicConfig(level=logging.DEBUG)

# %% [markdown]
# ## Define name-space for xml-parsing

# %%
xmlns = {"tei": "http://www.tei-c.org/ns/1.0", "xml":"http://www.w3.org/XML/1998/namespace", "": "http://www.tei-c.org/ns/1.0"}
for key in xmlns:
    ET.register_namespace(key, xmlns[key])

# %% [markdown]
# ## Access to the VICAV Zotero library
#
# * Use API_TOKEN from environment to access Zotero
# * Set the Zotero group id for VICAV here

# %%
request_headers = {'Authorization': 'Bearer ' + os.environ['API_TOKEN']}
group_id = "2165756"
limit_downloads_to = int(os.environ['LIMIT_DOWNLOADS_TO']) if 'LIMIT_DOWNLOADS_TO' in os.environ and os.environ['LIMIT_DOWNLOADS_TO'] else None
# On GitHub more than one connections to api.zotero.org was broken when this environment variable was introduced
conn_limit=int(os.environ['MAX_CONNECTIONS']) if 'MAX_CONNECTIONS' in os.environ and os.environ['MAX_CONNECTIONS'] else 4 
total_timeout=int(os.environ['TIMEOUT']) if 'TIMEOUT' in os.environ and os.environ['TIMEOUT'] else 5 #s
logging.info("limit_downloads_to = " + str(limit_downloads_to) + ", conn_limit = " + str(conn_limit) + ', total_timeout = ' + str(total_timeout) + 's')
# Out:
# 2026-03-10 16:42:47,077 - limit_downloads_to = None, conn_limit = 4, total_timeout = 5s

# %% [markdown]
# ## Read all items in the library
#
# Load items from Zotero group library
#
#     Args:
#         group_id (str): ID of a Zotero group
#         limit (int): number of items to retrieve from library, maximum is 100.
#         start (int): item number to start with

# %%
async def get_items(session, group_id:str,limit:int,start:int,itemType = None,format = None):
    request_url = "https://api.zotero.org/groups/" + group_id + "/items/" + "?limit=" + str(limit) + "&start=" + str(start) + ("&itemType="+itemType if itemType is not None else "") + ("&format="+format if format is not None else "")
    retries = 2
    while retries > 0:
        try:
            async with session.get(url=request_url, headers=request_headers) as response:
                if response.status == 200:
                    if format == "tei":
                        parsed = ET.fromstring(await response.read())
                    else:
                        parsed = json.loads(await response.text())
                    response_headers = response.headers
                    logging.info("Got "+request_url + (" Backoff: " + response.headers["Backoff"] if "Backoff" in response.headers else ""))
                    return parsed, response_headers
        except Exception as e:
            retries = retries - 1
            await asyncio.sleep(3 + random() + 0.5)
            logging.info("Retrying after " + type(e).__name__ + (": " + str(e) if str(e) else ""))

# %% [raw]
# async def test1():
#     conn = aiohttp.TCPConnector(limit=conn_limit)
#     timeout = aiohttp.ClientTimeout(total=total_timeout) # 10 min
#     async with aiohttp.ClientSession(connector=conn, timeout=timeout) as session:
#         test1, test_reponse_headers = await get_items(session, group_id,10,1000)
#         test1a, test_reponse_headersa = await get_items(session, group_id,10,300,"note")
#         print(test_reponse_headers, '\n', test_reponse_headersa, '\n', len(test1), ' ', len(test1a), '\n', test1)
# asyncio.run(test1())

# %% [markdown]
# Get total number of items in group library
#
#     Args:
#         group_id (str): ID of a Zotero group
#
#     Returns:
#         int: number of items in the library

# %%
def total_number_items(group_id) -> int:
    request_url = "https://api.zotero.org/groups/" + group_id + "/items/"
    response = requests.get(request_url, headers=request_headers)
    
    return int(response.headers["Total-Results"])

# %% [raw]
# test2 = total_number_items(group_id)
# print(test2)

# %% [markdown]
# Get headers of Zotero-Api-Calls
#
#     Args:
#         group_id (str): ID of a Zotero group

# %%
def get_headers(group_id):
    request_url = "https://api.zotero.org/groups/" + group_id + "/items/"
    response = requests.get(request_url, headers=request_headers)
    
    return response.headers

# %% [raw]
# test3 = get_headers(group_id)
# print(test3)

# %% [markdown]
# Get links from headers
#
#     Args:
#         headers: http-headers of a response
#
#     Returns:
#         dict

# %%
def get_links_from_headers(headers) -> dict:
    link_list = headers["Link"].split(",")
    links = {}
    for link_item in link_list:
        #print(link_item)
        link_type = link_item.split('; rel="')[1].replace('"','').strip()
        link_value = link_item.split('; rel="')[0].replace("<","").replace(">","").strip()
        links[link_type] = link_value
    
    return links

# %% [raw]
# test_headers = get_headers(group_id)
# test4 = get_links_from_headers(test_headers)
# print(test4)

# %% [markdown]
# ## Get all items of a collection/group lib
#
# * Generate all links with `for start in range(limit,last,limit)`.
# * Then download in parallel.

# %%
async def fetch(request_url, session, format = None):
    await asyncio.sleep(1 * random() + 0.5)
    retries = 2
    while retries > 0:
        try:
            async with session.get(request_url, headers=request_headers) as response:
                if format == "tei":
                    content = ET.fromstring(await response.read())
                else:
                    content = json.loads(await response.text())
                logging.info("Got "+request_url + (" Backoff: " + response.headers["Backoff"] if "Backoff" in response.headers else ""))
                return {"status": response.status, "data": content}
        except Exception as e:
            retries = retries - 1
            await asyncio.sleep(3 + random() + 0.5)
            logging.info("Retrying after " + type(e).__name__ + (": " + str(e) if str(e) else ""))

async def fetch_batch(url_list, format = None):
    conn = aiohttp.TCPConnector(limit=conn_limit)
    timeout = aiohttp.ClientTimeout(total=total_timeout)
    async with aiohttp.ClientSession(connector=conn, timeout=timeout) as session:
        responses = await asyncio.gather(*[fetch(url, session, format) for url in url_list])
    return responses

async def get_all_items(session, group_id, itemType = None, format = None):
    logging.info("Getting all items" + 
                 ((" of type " + itemType) if itemType is not None else "") + 
                 ((" formatted as " + format) if format is not None else "") + " now.")

    # settings to be used in the function to get the items (limit is max 100 per single request)
    limit=100
    start=0
    urls = []
    
    # get the first 200 items to start with
    first_round=await get_items(session, group_id,limit,start,itemType,format)
    allitems = first_round[0]
    
    # get the next link from the headers
    next_url = get_links_from_headers(first_round[1])["next"]
    last_url = get_links_from_headers(first_round[1])["last"]
    next_url_parsed = urlparse(next_url)
    parsed_qs = parse_qs(next_url_parsed.query)
    last_qs = parse_qs(urlparse(last_url).query)
    last_start = limit_downloads_to if limit_downloads_to is not None and format is not None else int(last_qs["start"][0])
    for start in range(limit, last_start+1, limit):
        parsed_qs["start"] = [start]
        parsed = next_url_parsed._replace(query=urlencode(parsed_qs, doseq=True))
        urls.append(parsed.geturl())
    i = 0
    while len(urls[i:i+conn_limit]) > 0:
        for response in await fetch_batch(urls[i:i+conn_limit], format):
            if isinstance(allitems, ET.Element) and isinstance(response["data"], ET.Element):
                for child in response["data"]:
                    allitems.append(child)
            else:
                allitems = allitems + response["data"]   
        i = i + conn_limit
    
    return allitems

# %% [raw]
# async def test5():
#     conn = aiohttp.TCPConnector(limit=conn_limit)
#     timeout = aiohttp.ClientTimeout(total=total_timeout)
#     async with aiohttp.ClientSession(connector=conn, timeout=timeout) as session:
#         test5 = await get_all_items(session, group_id)
#         print(test5)
# asyncio.run(test5())

# %% [markdown]
# Store all items of a group library in a json file
#
#     Args:
#         group_id (str): ID of a Zotero group
#         filename (str): name of the export file including file-extension
#
#     Returns:
#         bool: True if successful

# %%
def export_all_items_to_file(group_id,filename) ->bool: 
    allitems = get_all_items(group_id)
    with open(filename,"w") as f:
        json.dump(allitems, f)
    return True

# %% [raw]
# #export_all_items_to_file(group_id,"export_grouplib.json")
# with open("export_grouplib.json","w") as f:
#     json.dump(test5, f)
# all_items = test5

# %% [markdown]
# Store export in a file and get all item ids
#
# The export contains also the note items. These are child items of some other item in this export. They have a parent reference.
#
# There are also attachment items. These are child items of some other item in this export. Most of them have a parent reference but some don't have a parent item (anymore?)

# %%
json_file = "export_grouplib.json"
item_ids = []
note_ids = []
attachment_ids = []
async def get_generic_items(session):
    if os.path.isfile(json_file):
        logging.info("Grouplib export json already exists. Delete to fetch again (time consuming).")
        with open(json_file, 'r') as f:
            all_items = json.load(f)    
    else:
        all_items = await get_all_items(session, group_id)
    return all_items

async def get_export_json():
    conn = aiohttp.TCPConnector(limit=conn_limit)
    timeout = aiohttp.ClientTimeout(total=total_timeout)
    async with aiohttp.ClientSession(connector=conn, timeout=timeout) as session:
        all_items = await get_generic_items(session)
    # all_items = test5
    with open(json_file,"w") as f:
        json.dump(all_items, f)
        logging.info("Exported json.")
    
    for item in all_items:
        item_id = item["key"]
        item_type = item["data"]["itemType"]
        if item_type == 'note':
            note_ids.append(item_id)
        elif item_type == 'attachment':
            attachment_ids.append(item_id)
        else:
            item_ids.append(item_id)
    return all_items
all_items = asyncio.run(get_export_json())
all_items_map = {data["key"]:data for data in all_items}
all_notes_map = {data["data"]["parentItem"]:data for data in [all_items_map[id] for id in note_ids]}
all_attachments_map = {data["data"]["parentItem"] if "parentItem" in data["data"] else "ZZZZZZZZ":data for data in [all_items_map[id] for id in attachment_ids]}
# Out:
# 2026-03-10 16:43:28,985 - Getting all items now.
# 2026-03-10 16:43:32,997 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=0
# 2026-03-10 16:43:37,101 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=400
# 2026-03-10 16:43:37,908 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=100
# 2026-03-10 16:43:38,063 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=300
# 2026-03-10 16:43:38,185 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=200
# 2026-03-10 16:43:41,439 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=800
# 2026-03-10 16:43:42,990 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=500
# 2026-03-10 16:43:43,464 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=700
# 2026-03-10 16:43:43,839 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=600
# 2026-03-10 16:43:48,022 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=900
# 2026-03-10 16:43:48,762 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=1100
# 2026-03-10 16:43:48,766 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=1200
# 2026-03-10 16:43:48,900 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=1000
# 2026-03-10 16:43:53,534 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=1500
# 2026-03-10 16:43:53,538 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=1300
# 2026-03-10 16:43:53,911 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=1600
# 2026-03-10 16:43:54,051 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=1400
# 2026-03-10 16:43:56,842 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=1700
# 2026-03-10 16:43:56,950 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=2000
# 2026-03-10 16:43:59,039 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=1900
# 2026-03-10 16:43:59,137 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=1800
# 2026-03-10 16:44:01,987 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=2300
# 2026-03-10 16:44:02,247 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=2200
# 2026-03-10 16:44:02,399 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=2400
# 2026-03-10 16:44:02,836 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=2100
# 2026-03-10 16:44:06,154 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=2600
# 2026-03-10 16:44:06,450 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=2800
# 2026-03-10 16:44:07,633 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=2500
# 2026-03-10 16:44:07,801 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=2700
# 2026-03-10 16:44:10,841 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=3100
# 2026-03-10 16:44:11,132 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=3200
# 2026-03-10 16:44:11,567 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=3000
# 2026-03-10 16:44:11,689 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=2900
# 2026-03-10 16:44:15,055 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=3300
# 2026-03-10 16:44:15,091 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=3500
# 2026-03-10 16:44:15,892 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=3600
# 2026-03-10 16:44:16,079 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=3400
# 2026-03-10 16:44:19,240 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=3700
# 2026-03-10 16:44:19,256 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=3900
# 2026-03-10 16:44:19,515 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=4000
# 2026-03-10 16:44:19,723 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=3800
# 2026-03-10 16:44:22,936 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=4200
# 2026-03-10 16:44:24,302 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=4300
# 2026-03-10 16:44:24,316 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=4100
# 2026-03-10 16:44:24,627 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=4400
# 2026-03-10 16:44:27,308 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=4500
# 2026-03-10 16:44:27,763 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=4700
# 2026-03-10 16:44:28,076 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=4600
# 2026-03-10 16:44:28,228 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=4800
# 2026-03-10 16:44:31,754 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=4900
# 2026-03-10 16:44:31,845 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=5000
# 2026-03-10 16:44:32,425 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=5100
# 2026-03-10 16:44:33,948 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=5200
# 2026-03-10 16:44:36,784 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=5400
# 2026-03-10 16:44:37,608 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=5600
# 2026-03-10 16:44:37,919 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=5500
# 2026-03-10 16:44:39,787 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=5300
# 2026-03-10 16:44:42,677 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=5900
# 2026-03-10 16:44:42,857 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=5700
# 2026-03-10 16:44:43,503 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=5800
# 2026-03-10 16:44:43,813 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=6000
# 2026-03-10 16:44:45,555 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=6200
# 2026-03-10 16:44:46,939 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=6100
# 2026-03-10 16:44:47,698 - Exported json.

# %% [raw]
# print(len(all_items), ' ', len(note_ids), ' ', len(item_ids), '\n', item_ids[:10],
#       '\nBibl items:\n', dict(list(all_items_map.items())[:10]),
#       '\nNote items:\n', dict(list(all_notes_map.items())[:10]),
#       '\nAttachement items:\n', dict(list(all_attachments_map.items())[:10]))

# %% [markdown]
# ## replace xml:id with biblid from extra-field
#
# Most (but currently not all) Zotero items should have a canonical biblid assigned. This function gets the value from data/extra and
# tries to extract the canonical biblid

# %%
def is_valid_xml_id(id):
    # https://stackoverflow.com/questions/55038323/how-to-write-a-regex-expression-to-check-a-valid-xml-element-ncname-in-javascrip
    p = re.compile(r"^[a-zA-Z_][\w.-]*$")
    matches = p.match(id)
    if matches:
        return True
    else:
        return False

# %%
malformedBiblIDs=[]
def get_biblid_from_extra(item):
    if "extra" in item["data"]:
        if item["data"]["extra"] != "":
            if "(biblid:" in item["data"]["extra"]:
                biblid=item["data"]["extra"].split(":")[1].replace(")","")
                if is_valid_xml_id(biblid):
                    return biblid
                else:
                    msg=item["key"] + " malformed biblid: " + item["data"]["extra"]
                    logging.info(msg)
                    malformedBiblIDs.append(msg)
                    return None
                    
            else:
                msg=item["key"] + " malformed biblid: " + item["data"]["extra"]
                logging.info(msg)
                malformedBiblIDs.append(msg)
                return None
        else:
            msg=item["key"] + " no biblid"
            logging.info(msg)
            malformedBiblIDs.append(msg)
            return None

# %% [raw]
# get_biblid_from_extra(all_items[2])

# %% [raw]
# for item in all_items[0:20]:
#     print(get_biblid_from_extra(item))

# %%
biblid_by_zuid={item["key"]: get_biblid_from_extra(item)
               for item in all_items}
# Out:
# 2026-03-10 16:45:01,363 - YKAAZ8W9 no biblid
# 2026-03-10 16:45:01,365 - QQFZ6WNB no biblid
# 2026-03-10 16:45:01,366 - X65CZ42K no biblid
# 2026-03-10 16:45:01,368 - 9ZZHBVLX malformed biblid: (biblid:Önel_2024_2819)
# 2026-03-10 16:45:01,372 - LJT59BIG no biblid
# 2026-03-10 16:45:01,374 - BSUNXBUT no biblid
# 2026-03-10 16:45:01,375 - ITRWL9TA malformed biblid: (Biblid: Procházka_2025_1234)
# 2026-03-10 16:45:01,377 - D58FGPG2 no biblid
# 2026-03-10 16:45:01,380 - NW86KV3L no biblid
# 2026-03-10 16:45:01,381 - TZAXDEL7 no biblid
# 2026-03-10 16:45:01,381 - 5I4JPUQI no biblid
# 2026-03-10 16:45:01,382 - S66B9IKA no biblid
# 2026-03-10 16:45:01,383 - 9RSV5QG8 no biblid
# 2026-03-10 16:45:01,385 - 7E8JT8GM no biblid
# 2026-03-10 16:45:01,386 - AN9KUERP malformed biblid: biblid:klimiuk_labidi_2025_6523)
# 2026-03-10 16:45:01,387 - 6XEFCL3B no biblid
# 2026-03-10 16:45:01,388 - BSB8YGNA no biblid
# 2026-03-10 16:45:01,389 - PQ9MSXMF no biblid
# 2026-03-10 16:45:01,390 - HY5JA5X3 no biblid
# 2026-03-10 16:45:01,392 - R7VKGD6X no biblid
# 2026-03-10 16:45:01,393 - 3UTYC4WG malformed biblid: (biblid:d'anna_2024_8200)
# 2026-03-10 16:45:01,394 - AT7ZC2DG malformed biblid: (biblid:

# %% [raw]
# biblid_by_zuid["D25ZTU9X"]

# %% [markdown]
# ## Get the geo data and replace tags with geo refs
#
# geo data is in `../../vicav_biblio/vicav_geodata.xml`

# %%
geo_data = ET.parse("../../010_manannot/vicav_geodata.xml")
geo_parent_map = {c:p for p in geo_data.iter( ) for c in p}
place_by_name = {placeName.text: 
                 {"type": geo_parent_map[placeName].get("type"),
                  "geo": geo_parent_map[placeName].find("./tei:location/tei:geo[@decls='#dd']",xmlns).text,
                  "el": geo_parent_map[placeName]}
                for placeName in geo_data.findall(".//tei:listPlace/tei:place/tei:placeName", xmlns)}

# %% [raw]
# #place_by_name = {}
# #p=1
# #for placeName in geo_data.findall(".//tei:listPlace/tei:place/tei:placeName", xmlns):
# #    p=p+1
# #    try:
# #        place_by_name = {**place_by_name, **{placeName.text: {"type": geo_parent_map[placeName].get("type"),
# #                                                              "geo": geo_parent_map[placeName].find("./tei:location/tei:geo[@decls='#dd']",xmlns).text,
# #                                                              "el": geo_parent_map[placeName]}}}
# #    except AttributeError:
# #        logging.info("Pos "+str(p)+" :"+str(ET.tostring(geo_parent_map[placeName])))
#
# print(geo_data.find(".//tei:listPlace", xmlns)[1].attrib["{http://www.w3.org/XML/1998/namespace}id"], '\n',
#     dict(list(place_by_name.items())[:10]))

# %% [markdown]
# # Get the current mapping for @n to Zoteros unique ID
#
# Zotero suggests readable @xml:id, we use them for @n, but those are not unique between runs or
# take into account that there may be more than one works by one author in a year.

# %%
get_zotero_unique_id = re.compile(r'https?://zotero.org/groups/[\d]+/items/(?P<zuid>[A-Z0-9]+)')
current_bibl_data = ET.parse("../../010_manannot/vicav_biblio_tei_zotero.xml")
n_by_zuid = {get_zotero_unique_id.match(bibStr.get("corresp")).groupdict()["zuid"]: bibStr.get("n")
                 for bibStr in current_bibl_data.findall(".//tei:biblStruct", xmlns)}
zuid_by_n = {bibStr.get("n"): get_zotero_unique_id.match(bibStr.get("corresp")).groupdict()["zuid"]
                 for bibStr in current_bibl_data.findall(".//tei:biblStruct", xmlns)}
duplicate_xmlid = {}

# %% [raw]
# n_by_zuid = {}
# for bibStr in current_bibl_data.findall(".//tei:biblStruct", xmlns):
#     try:
#         n_by_zuid = {**n_by_zuid,
#                          **{get_zotero_unique_id.match(bibStr.get("corresp")).groupdict()["zuid"]: bibStr.get("n")}
#                         }
#     except AttributeError:
#         logging.info(ET.tostring(bibStr))
# m = get_zotero_unique_id.match("http://zotero.org/groups/2165756/items/5XHDCICS")
# m.groupdict()
# n_by_zuid

# %% [markdown]
# ## Get all TEIs from Zotero
#
# man nimmt die Liste mit den IDs der entries, baut für jeden entry die URL nach dem Muster
# https://api.zotero.org/groups/2165756/items/944KQVKQ?format=tei
# man lädt das mit GET requesst
# dann aus dem response den body und parsed das mit ET from string, nimmt daraus das
# `<biblStruct>` Element;
# baut eine gemeinsame `<listBibl>` und fügt das geparste Element ein,
# dann dumpt man den ganzen Element-Tree
#
# ### Retrieves TEI of an item generated by Zotero
#
# Resolves place names to geo coordinates using the place by name dict created above.
#
# ### Keeping the xml:ids stable
#
# The code uses the Zotero unique ids to look up the @xml:id in the current bibliography and change it to that if it is needed.
# Additionally if the id of the entry just downloaded does not match the known Zotero unique id a new unique @xml:id is generated appending b-z.
# This code is not tested very much for corner cases. It should be replaced by getting the canonical biblid from the downloaded data.

# %%
ET.register_namespace("", "http://www.tei-c.org/ns/1.0")
tag_parser = re.compile(r'(?P<geo_type>[^:]+):(?P<geo_name>[^[]+)(\[(?P<long>[\d.,]+) +(?P<lat>[\d.,]+)])?')

def create_geo_tag(tags_el, tag):
    #starts with reg: geo: diaGroup: -> lookup, get geo location and create elemnt
    # uses PEP 634, requires python 3.10+
    m = tag_parser.match(tag)
    if m is not None:
        match m.groupdict():
            case {"geo_type": "reg" | "geo" | "diaGroup", "geo_name": geo_name, "long": long, "lat": lat}:
                tag_note_el = ET.SubElement(tags_el, "note", type="tag")
                geo_name = geo_name.rstrip()
                ET.SubElement(tag_note_el, "name", type=m.groupdict()["geo_type"]).text = geo_name
                if geo_name in place_by_name:
                    ET.SubElement(tag_note_el, "geo").text = place_by_name[geo_name]["geo"]
                else:
                    ET.SubElement(tag_note_el, "note", type="missing_geo_data")
                return tag_note_el
    if tag in place_by_name:
        tag_note_el = ET.SubElement(tags_el, "note", type="tag", subtype="unmarked_geo")
        ET.SubElement(tag_note_el, "name", type=place_by_name[tag]["type"]).text = tag
        ET.SubElement(tag_note_el, "geo").text = place_by_name[tag]["geo"]
        return tag_note_el
    ret = ET.SubElement(tags_el, "note", type="tag")
    ret.text = tag
    return ret

def extend_item_tei(bibl):
    try:
        zuid = get_zotero_unique_id.match(bibl.get("corresp")).groupdict()["zuid"]
        logging.debug("Zoterio unique ID: " + zuid)
        zotero_xmlid = bibl.get("{http://www.w3.org/XML/1998/namespace}id")
        logging.debug("zotero @xml:id: " + zotero_xmlid)        
        bibl.set("n", zotero_xmlid)
        if zuid in n_by_zuid and zotero_xmlid != n_by_zuid[zuid]:
            bibl.set("n", n_by_zuid[zuid])
            logging.info("Changed @n for item " + zuid + " from "+ zotero_xmlid + " to " + n_by_zuid[zuid] + ".")
        elif zotero_xmlid in zuid_by_n and zuid_by_n[zotero_xmlid] != zuid:
            initial_xmlid = zotero_xmlid
            if not zotero_xmlid in duplicate_xmlid:
                duplicate_xmlid[zotero_xmlid] = zotero_xmlid + "b"
            else:
                duplicate_xmlid[zotero_xmlid] = duplicate_xmlid[zotero_xmlid][:-1] + chr(ord(duplicate_xmlid[zotero_xmlid][-1]) + 1)
            zotero_xmlid = duplicate_xmlid[zotero_xmlid]
            if zotero_xmlid in zuid_by_n and zuid_by_n[zotero_xmlid] != zuid:
                logging.error("genereated @n for item " + zuid + " is in use!")
            bibl.set("n", zotero_xmlid)            
            logging.info("Changed @n for item " + zuid + " from "+ initial_xmlid +
                         " to " + zotero_xmlid + " (duplicate of " + zuid_by_n[initial_xmlid] + ")")
        if zuid in biblid_by_zuid and biblid_by_zuid[zuid] is not None:
            bibl.set("{http://www.w3.org/XML/1998/namespace}id", biblid_by_zuid[zuid])
        if zuid in all_notes_map:
            note_for_zuid = all_notes_map[zuid]["data"]["note"].replace("&", "&amp;")
            parsed_note = ET.fromstring("<note>"+note_for_zuid+"</note>")
            bibl.append(parsed_note)
        
        tags = all_items_map[zuid]["data"]["tags"]
        if len(tags) > 0:
            tags_el = ET.SubElement(bibl, "note", type="tags")
            for o in tags:
                create_geo_tag(tags_el, o["tag"])
        
        meeting_name = all_items_map[zuid]["data"].get("meetingName")

        if meeting_name is not None:
            meeting_date = all_items_map[zuid]["data"].get("date")
            meeting_place = all_items_map[zuid]["data"].get("place")
            meeting_el = ET.Element("meeting")
            ET.SubElement(meeting_el, "name").text = meeting_name
            ET.SubElement(meeting_el, "date").text = meeting_date
            ET.SubElement(meeting_el, "placeName").text = meeting_place
            monogr_el = bibl.find("tei:monogr",xmlns)
            monogr_el.insert(0,meeting_el)

        abstract = all_items_map[zuid]["data"].get("abstractNote")
        if abstract is not None and abstract != "":
            abstract_el = ET.SubElement(bibl, "note", type="abstract")
            abstract_el.text = abstract

    except xml.etree.ElementTree.ParseError:
        logging.info("XML parser error in notes for item id "+zuid+"\n"+note_for_zuid)
    if bibl is None:
        logging.debug("No biblStruct in item " + zuid)
    logging.debug("Extended TEI for " + zuid)

async def get_item_tei(group_id,item_id,session):
    request_url = "https://api.zotero.org/groups/" + group_id + "/items/" + item_id + "?format=tei"
    bibl = None
    note_for_item_id = ""
    response_text = ""
    try:
        async with session.get(url=request_url, headers=request_headers) as response:
            response_text = await response.text()
        list_bibl = ET.fromstring(response_text)
        bibl = list_bibl.find("tei:biblStruct",xmlns)
        logging.debug("XML: " + ET.tostring(bibl, encoding="unicode"))
        if bibl is None:
            logging.info("There is no biblStruct in the response for item " + item_id +":\n"+response_text)
            return bibl
        extend_item_tei(bibl)
    except asyncio.TimeoutError:
        logging.info("Timeout fetching " + item_id)
    if bibl is None:
        logging.debug("No biblStruct in item " + item_id)
    logging.info("Fetched TEI for " + item_id)
    return bibl

# %%
async def get_item_tei_test():
    conn = aiohttp.TCPConnector(limit=conn_limit)
    timeout = aiohttp.ClientTimeout(total=total_timeout)
    async with aiohttp.ClientSession(connector=conn) as session:
        #test = await get_item_tei(group_id,"944KQVKQ",session)
        #test = await get_item_tei(group_id,"DXNCFAMR",session)
        #test = await get_item_tei(group_id,"6QNLQCG9",session)
        #test = await get_item_tei(group_id,"944KQVKQ",session)
        #test = await get_item_tei(group_id,"6BGIGGVN",session)
        test = await get_item_tei(group_id,"3BUJBNPK",session)
    ET.indent(test)
    ET.dump(test)
asyncio.run(get_item_tei_test())
# Out:
# 2026-03-10 16:45:09,326 - Changed @n for item 3BUJBNPK from Woidich2007 to Woidich2007a.
# 2026-03-10 16:45:09,327 - Fetched TEI for 3BUJBNPK
# <biblStruct xmlns="http://www.tei-c.org/ns/1.0" type="journalArticle" xml:id="woidich_2007_0001" corresp="http://zotero.org/groups/2165756/items/3BUJBNPK" n="Woidich2007a">
#   <analytic>
#     <title level="a">Everything you always wanted to know about 'āl, yi'ūl "to say" in Egyptian Arabic</title>
#     <author>
#       <forename>Manfred</forename>
#       <surname>Woidich</surname>
#     </author>
#   </analytic>
#   <monogr>
#     <imprint>
#       <biblScope unit="page">675-700</biblScope>
#       <date>2007</date>
#     </imprint>
#   </monogr>
#   <note type="tags">
#     <note type="tag">
#       <name type="reg">Egypt</name>
#       <geo>27.000000 30.000000</geo>
#     </note>
#     <note type="tag">
#       <name type="reg">Egypt-Sudan</name>
#       <geo>22.316667 30.100000</geo>
#     </note>
#   </note>
# </biblStruct>

# %% [raw]
# print("Notes:\n", all_notes_map["944KQVKQ"]["data"]["note"], "\nTags:\n", all_items_map["944KQVKQ"]["data"]["tags"])

# %%
template = ET.parse("listbibl_template.xml")
sourceDesc = template.find(".//tei:sourceDesc/tei:p", xmlns)
now=datetime.now()
dateTimeString="{:%Y-%m-%d %H:%M:%S}".format(now)
sourceDesc.text = sourceDesc.text.replace("{dateTime}", dateTimeString)
list_bibl = template.find("tei:text/tei:body/tei:listBibl",xmlns)

# %% [markdown]
# ### Load template containing a listBibl-element that will be filled with the retrieved biblStruct elements

# %% [raw]
# ET.dump(list_bibl)
# list_bibl.append(test)
# ET.dump(list_bibl)

# %% [markdown]
# ## Get the TEI
#
# * For each item-id get the TEI and append it to list-bibl
# * Save the resulting XML
# * Use the same method as for the JSON for the whole group lib
# * Then download in parallel.
#
# We need to consider https://www.zotero.org/support/dev/web_api/v3/basics#rate_limiting
#
# TODO: Maybe only get the all the top items in the group with https://api.zotero.org/groups/2165756/items/top?format=tei&limit=100&sort=creator

# %%
async def async_download():
    conn = aiohttp.TCPConnector(limit=conn_limit)
    timeout = aiohttp.ClientTimeout(total=total_timeout)
    async with aiohttp.ClientSession(connector=conn, timeout=timeout) as session:
        all_items = await get_all_items(session, group_id, format = "tei")
    return all_items

all_items = asyncio.run(async_download())
for bibl in all_items:
    extend_item_tei(bibl)
all_items[:] = sorted(all_items, key=lambda child: child.get("{http://www.w3.org/XML/1998/namespace}id"))
for item in all_items:
    list_bibl.append(item)

pathToZoteroExport='../../010_manannot/vicav_biblio_tei_zotero.xml'
with open(pathToZoteroExport, 'wb') as f:
    ET.indent(template)
    template.write(f, encoding='utf-8',xml_declaration=True)
    logging.info("TEI export done.")
# Out:
# 2026-03-10 16:57:30,857 - Getting all items formatted as tei now.
# 2026-03-10 16:57:34,173 - Got https://api.zotero.org/groups/2165756/items/?limit=100&start=0&format=tei
# 2026-03-10 16:57:36,661 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=300
# 2026-03-10 16:57:37,660 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=100
# 2026-03-10 16:57:38,147 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=400
# 2026-03-10 16:57:38,706 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=200
# 2026-03-10 16:57:40,903 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=700
# 2026-03-10 16:57:41,366 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=800
# 2026-03-10 16:57:41,482 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=600
# 2026-03-10 16:57:41,657 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=500
# 2026-03-10 16:57:44,395 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=1000
# 2026-03-10 16:57:45,315 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=1200
# 2026-03-10 16:57:46,168 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=900
# 2026-03-10 16:57:46,299 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=1100
# 2026-03-10 16:57:48,986 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=1300
# 2026-03-10 16:57:49,656 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=1400
# 2026-03-10 16:57:50,037 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=1500
# 2026-03-10 16:57:50,881 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=1600
# 2026-03-10 16:57:53,611 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=1700
# 2026-03-10 16:57:53,905 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=1900
# 2026-03-10 16:57:54,322 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=1800
# 2026-03-10 16:57:54,647 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=2000
# 2026-03-10 16:57:58,118 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=2300
# 2026-03-10 16:57:58,368 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=2400
# 2026-03-10 16:57:58,676 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=2100
# 2026-03-10 16:57:58,952 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=2200
# 2026-03-10 16:58:01,268 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=2800
# 2026-03-10 16:58:02,132 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=2700
# 2026-03-10 16:58:02,450 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=2500
# 2026-03-10 16:58:02,831 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=2600
# 2026-03-10 16:58:06,200 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=3200
# 2026-03-10 16:58:06,845 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=2900
# 2026-03-10 16:58:06,958 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=3100
# 2026-03-10 16:58:07,050 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=3000
# 2026-03-10 16:58:09,892 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=3400
# 2026-03-10 16:58:10,673 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=3600
# 2026-03-10 16:58:10,968 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=3300
# 2026-03-10 16:58:11,498 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=3500
# 2026-03-10 16:58:14,272 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=3900
# 2026-03-10 16:58:14,286 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=4000
# 2026-03-10 16:58:14,500 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=3700
# 2026-03-10 16:58:14,961 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=3800
# 2026-03-10 16:58:17,777 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=4400
# 2026-03-10 16:58:18,573 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=4200
# 2026-03-10 16:58:18,720 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=4300
# 2026-03-10 16:58:18,781 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=4100
# 2026-03-10 16:58:22,120 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=4800
# 2026-03-10 16:58:22,778 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=4700
# 2026-03-10 16:58:22,824 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=4600
# 2026-03-10 16:58:22,993 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=4500
# 2026-03-10 16:58:26,348 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=4900
# 2026-03-10 16:58:26,673 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=5200
# 2026-03-10 16:58:27,269 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=5000
# 2026-03-10 16:58:27,362 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=5100
# 2026-03-10 16:58:29,590 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=5400
# 2026-03-10 16:58:29,669 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=5600
# 2026-03-10 16:58:30,013 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=5300
# 2026-03-10 16:58:30,090 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=5500
# 2026-03-10 16:58:32,151 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=6000
# 2026-03-10 16:58:32,746 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=5700
# 2026-03-10 16:58:33,005 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=5800
# 2026-03-10 16:58:33,197 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=5900
# 2026-03-10 16:58:34,759 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=6200
# 2026-03-10 16:58:35,483 - Got https://api.zotero.org/groups/2165756/items/?format=tei&limit=100&start=6100
# 2026-03-10 16:58:35,508 - Changed @n for item EYRLTZH8 from Bozkurt2022 to Bozkurt_Volkan2022.
# 2026-03-10 16:58:35,509 - Changed @n for item ZQHJXZR6 from Procházka2025 to Procházka2025b.
# 2026-03-10 16:58:35,509 - Changed @n for item G8QR79BE from Klimiuk2022b to Morano_Roberta2022.
# 2026-03-10 16:58:35,510 - Changed @n for item 6V5G835V from Behnstedt to Behnstedtb.
# 2026-03-10 16:58:35,510 - Changed @n for item FGX9QE2F from Torzullo2018 to Torzullo_Antonella2018.
# 2026-03-10 16:58:35,511 - Changed @n for item QG44DRGJ from Torzullo2022 to Torzullo2022b.
# 2026-03-10 16:58:35,512 - Changed @n for item 2ZYNZ9PF from Procházka2022 to Procházka2022b.
# 2026-03-10 16:58:35,512 - Changed @n for item ZDWIGNHB from Taine-Cheikh2025 to Taine-Cheikh2025b.
# 2026-03-10 16:58:35,513 - Changed @n for item WKDXPTPY from Corriente1995 to Corriente1995b.
# 2026-03-10 16:58:35,514 - Changed @n for item J3CHN3IX from Frayha1973 to Frayha1973a.
# 2026-03-10 16:58:35,514 - Changed @n for item ULSB2IK2 from Baccouche2000 to Baccouche2000b.
# 2026-03-10 16:58:35,515 - Changed @n for item F7I8GR8L from Ritt-Benmimoun2012 to Ritt-Benmimoun2012a.
# 2026-03-10 16:58:35,516 - Changed @n for item B6DHL6BY from Quitout1999 to Quitout1999c.
# 2026-03-10 16:58:35,517 - Changed @n for item JA675QVW from Aguadé2004 to Aguadé2004a.
# 2026-03-10 16:58:35,517 - Changed @n for item NSD7SUSS from Rossi1938 to Rossi1938a.
# 2026-03-10 16:58:35,518 - Changed @n for item R8FL69PN from Durand1995 to Durand1995a.
# 2026-03-10 16:58:35,519 - Changed @n for item G86IMNJ5 from Cifoletti2002 to Cifoletti2002b.
# 2026-03-10 16:58:35,520 - Changed @n for item V3F2XIZ5 from Lévy1991 to Lévy1991b.
# 2026-03-10 16:58:35,521 - Changed @n for item 7BMZ86TF from Marçais1956 to Marçais1956a.
# 2026-03-10 16:58:35,522 - Changed @n for item 4RSMIKAU from Moscoso_García2002 to Moscoso_García2002b.
# 2026-03-10 16:58:35,522 - Changed @n for item 96IHQD7Z from Ould_Mohamed_Baba1999a to Ould_Mohamed_Baba1999b.
# 2026-03-10 16:58:35,523 - Changed @n for item ZT2ZLGR3 from Ould_Mohamed_Baba2014 to Ould_Mohamed_Baba2014b.
# 2026-03-10 16:58:35,524 - Changed @n for item B2JFJWPQ from Jouin1973 to Jouin1973a.
# 2026-03-10 16:58:35,526 - Changed @n for item MPP5JK4W from Corriente1998 to Corriente1998c.
# 2026-03-10 16:58:35,527 - Changed @n for item VSST3GS7 from Caubet2005 to Caubet2005b.
# 2026-03-10 16:58:35,528 - Changed @n for item H6P53C7N from Caubet2000 to Caubet2000a.
# 2026-03-10 16:58:35,528 - Changed @n for item MUHLBHSG from Caubet1999 to Caubet1999b.
# 2026-03-10 16:58:35,529 - Changed @n for item LPALQSZ9 from Caubet1998 to Caubet1998b.
# 2026-03-10 16:58:35,529 - Changed @n for item 25UFNVBR from Brunot1950 to Brunot1950a.
# 2026-03-10 16:58:35,530 - Changed @n for item LKHVEAT5 from Brunot1923 to Brunot1923a.
# 2026-03-10 16:58:35,531 - Changed @n for item FWH5VSQ9 from Ruiter2006 to Ruiter2006b.
# 2026-03-10 16:58:35,532 - Changed @n for item 876YIKKP from Moscoso_García2009 to Moscoso_García2009b.
# 2026-03-10 16:58:35,532 - Changed @n for item 33QX8KKI from Ould_Mohamed_Baba2001 to Ould_Mohamed_Baba2001b.
# 2026-03-10 16:58:35,533 - Changed @n for item QNZ5HTM7 from Ould_Mohamed_Baba1998 to Ould_Mohamed_Baba1998b.
# 2026-03-10 16:58:35,534 - Changed @n for item NLFM9BNU from Ould_Mohamed_Baba2008b to Ould_Mohamed_Baba2008c.
# 2026-03-10 16:58:35,535 - Changed @n for item XZJYMULK from Ould_Mohamed_Baba1999b to Ould_Mohamed_Baba1999a.
# 2026-03-10 16:58:35,536 - Changed @n for item 6IY3S8MX from Ould_Mohamed_Baba2006 to Ould_Mohamed_Baba2006a.
# 2026-03-10 16:58:35,536 - Changed @n for item HELVL6RU from Ould_Mohamed_Baba2004 to Ould_Mohamed_Baba2004a.
# 2026-03-10 16:58:35,537 - Changed @n for item R2BXLS7M from Moscoso2001a to Moscoso2001c.
# 2026-03-10 16:58:35,538 - Changed @n for item AK4PJLCN from Moscoso1999 to Moscoso1999a.
# 2026-03-10 16:58:35,539 - Changed @n for item ZYU7CUCT from Herrero_Muñoz-Cobo1996 to Herrero_Muñoz-Cobo1996a.
# 2026-03-10 16:58:35,540 - Changed @n for item FR2W8JYL from Guerrero2015 to Guerrero2015b.
# 2026-03-10 16:58:35,541 - Changed @n for item N4YF9QYV from Guerrero2012 to Guerrero2012a.
# 2026-03-10 16:58:35,541 - Changed @n for item 44MEDFXC from Geva-Kleinberger2012 to Geva-Kleinberger2012a.
# 2026-03-10 16:58:35,542 - Changed @n for item ITH9K5B7 from Ferrando2000 to Ferrando2000d.
# 2026-03-10 16:58:35,543 - Changed @n for item 7UFQVKFI from Ferrando1998 to Ferrando1998a.
# 2026-03-10 16:58:35,544 - Changed @n for item CP7HPQ4I from Ferrando_Frutos1995 to Ferrando_Frutos1995a.
# 2026-03-10 16:58:35,545 - Changed @n for item QHUCBNQU from Corriente2008 to Corriente2008c.
# 2026-03-10 16:58:35,546 - Changed @n for item MEPXGM8T from Corriente1999 to Corriente1999a.
# 2026-03-10 16:58:35,547 - Changed @n for item 2VAJPMDK from Corriente1998 to Corriente1998b.
# 2026-03-10 16:58:35,547 - Changed @n for item YSWL2YZG from Corriente1997 to Corriente1997b.
# 2026-03-10 16:58:35,548 - Changed @n for item G4KEFPPS from Guerrero2012 to Guerrero2012b.
# 2026-03-10 16:58:35,549 - Changed @n for item E9GPRW8Y from Herrero_Muñoz-Cobo1996 to Herrero_Muñoz-Cobo1996b.
# 2026-03-10 16:58:35,550 - Changed @n for item U5BMXQAS from Herrero_Muñoz-Cobo1998 to Herrero_Muñoz-Cobo1998b.
# 2026-03-10 16:58:35,551 - Changed @n for item YENBFTCU from Herrero_Muñoz-Cobo2008 to Herrero_Muñoz-Cobo2008a.
# 2026-03-10 16:58:35,552 - Changed @n for item T2AI3B73 from Lévy1992 to Lévy1992b.
# 2026-03-10 16:58:35,553 - Changed @n for item 7PHHWJR2 from Lévy1995 to Lévy1995a.
# 2026-03-10 16:58:35,553 - Changed @n for item DNKRBJHA from Moscoso_García2007 to Moscoso_García2007d.
# 2026-03-10 16:58:35,554 - Changed @n for item YLJXQV5P from Moscoso2003 to Moscoso2003a.
# 2026-03-10 16:58:35,555 - Changed @n for item JM5WHLPS from Moscoso2001 to Moscoso2001a.
# 2026-03-10 16:58:35,557 - Changed @n for item 2HWBBYHS from Singer1973 to Singer1973a.
# 2026-03-10 16:58:35,558 - Changed @n for item LWRGGBLB from Corriente1995 to Corriente1995a.
# 2026-03-10 16:58:35,558 - Changed @n for item 4BSKPNSM from Corriente1994 to Corriente1994b.
# 2026-03-10 16:58:35,559 - Changed @n for item EQEBF4WE from Corriente1989b to Corriente1989c.
# 2026-03-10 16:58:35,560 - Changed @n for item KLBRZ5L7 from Chikovani2004 to Chikovani2004b.
# 2026-03-10 16:58:35,562 - Changed @n for item 3LK9IWCK from Aguadé1996 to Aguadé1996c.
# 2026-03-10 16:58:35,563 - Changed @n for item 565AX8JL from Ritt-Benmimoun2023 to Ritt-Benmimoun2023a.
# 2026-03-10 16:58:35,564 - Changed @n for item LAXZNM5B from Ritt-Benmimoun2022 to Ritt-Benmimoun2022c.
# 2026-03-10 16:58:35,565 - Changed @n for item TF64NIH7 from Maas1999 to Maas1999b.
# 2026-03-10 16:58:35,565 - Changed @n for item 54KJWHNR from Luffin2013 to Luffin2013b.
# 2026-03-10 16:58:35,566 - Changed @n for item GJEQ7B4A from Khan2018 to Khan2018d.
# 2026-03-10 16:58:35,567 - Changed @n for item PBE9AZD7 from Jastrow2009 to Jastrow2009b.
# 2026-03-10 16:58:35,568 - Changed @n for item VV7FPX34 from Jastrow2006 to Jastrow2006a.
# 2026-03-10 16:58:35,568 - Changed @n for item LS8VQPE4 from Ingham1991 to Ingham1991b.
# 2026-03-10 16:58:35,570 - Changed @n for item DZQMEE4M from Eid1992 to Eid1992a.
# 2026-03-10 16:58:35,573 - Changed @n for item XH654DJX from Fischer1899 to Fischer1899b.
# 2026-03-10 16:58:35,574 - Changed @n for item X9RPWLEV from Ferrando1998 to Ferrando1998b.
# 2026-03-10 16:58:35,575 - Changed @n for item WEJ3WZC2 from Ferguson1997 to Ferguson1997g.
# 2026-03-10 16:58:35,576 - Changed @n for item BQ3CB9K6 from Dickins2011 to Dickins2011b.
# 2026-03-10 16:58:35,578 - Changed @n for item UKBNFHNS from Caubet2018 to Caubet2018a.
# 2026-03-10 16:58:35,579 - Changed @n for item M8QDLWH6 from Lévy1994 to Lévy1994c.
# 2026-03-10 16:58:35,579 - Changed @n for item DH9FZ3HU from Lévy1991 to Lévy1991a.
# 2026-03-10 16:58:35,580 - Changed @n for item WYYMTRRT from Langone2003 to Langone2003a.
# 2026-03-10 16:58:35,582 - Changed @n for item IRILEVD2 from Lahdo2010 to Lahdo2010a.
# 2026-03-10 16:58:35,582 - Changed @n for item SNV2EJLN from Kurpershoek2005 to Kupershoek2005.
# 2026-03-10 16:58:35,583 - Changed @n for item YMGDYAJB from Kheshaifaty1993 to Kheshaifaty1993b.
# 2026-03-10 16:58:35,584 - Changed @n for item N3FFYQEH from Johnstone1967 to Johnstone1967b.
# 2026-03-10 16:58:35,585 - Changed @n for item 6PLLR6UU from Johnstone1964 to Johnstone1964b.
# 2026-03-10 16:58:35,586 - Changed @n for item 24KSC8XD from Ingham1997 to Ingham1997b.
# 2026-03-10 16:58:35,587 - Changed @n for item ELB7YYFT from Ingham2006a to Ingham2006b.
# 2026-03-10 16:58:35,587 - Changed @n for item IDS87EKB from Ingham2006b to Ingham2006a.
# 2026-03-10 16:58:35,588 - Changed @n for item 5JDPT73C from Ingham2004 to Ingham2004a.
# 2026-03-10 16:58:35,589 - Changed @n for item 9TAXB9NH from Ingham2002a to Ingham2002b.
# 2026-03-10 16:58:35,589 - Changed @n for item YBYZKS8B from Ingham2002b to Ingham2002a.
# 2026-03-10 16:58:35,590 - Changed @n for item Q2A2B8WX from Ingham1994 to Ingham1994a.
# 2026-03-10 16:58:35,591 - Changed @n for item 8MJL5V8K from Ingham1991 to Ingham1991a.
# 2026-03-10 16:58:35,592 - Changed @n for item BZ9ERDSF from Ingham1986 to Ingham1986a.
# 2026-03-10 16:58:35,593 - Changed @n for item HEPC5YD4 from Ingham1982a to Ingham1982b.
# 2026-03-10 16:58:35,593 - Changed @n for item NQZK2Z4R from Ingham1982b to Ingham1982a.
# 2026-03-10 16:58:35,595 - Changed @n for item AWUWP4HN from Ingham1980 to Ingham1980a.
# 2026-03-10 16:58:35,595 - Changed @n for item U8J83IE4 from Holes2006 to Holes2006b.
# 2026-03-10 16:58:35,596 - Changed @n for item MZQG7Y9X from Holes2005a to Holes2005c.
# 2026-03-10 16:58:35,597 - Changed @n for item L2XHDPAC from Holes2013 to Holes2013c.
# 2026-03-10 16:58:35,598 - Changed @n for item N6D7SIDZ from Holes2005b to Holes2005a.
# 2026-03-10 16:58:35,598 - Changed @n for item UIGY9NBQ from Holes2004 to Holes2004c.
# 2026-03-10 16:58:35,599 - Changed @n for item BFQETL9Y from Holes1986 to Holes1986c.
# 2026-03-10 16:58:35,600 - Changed @n for item QP6IGT3I from Holes1983 to Holes1983a.
# 2026-03-10 16:58:35,601 - Changed @n for item GM867C9T from de_Jong2013 to de_Jong2013g.
# 2026-03-10 16:58:35,602 - Changed @n for item Q6K3LUCU from Borg1999 to Borg1999b.
# 2026-03-10 16:58:35,602 - Changed @n for item B8MUPTAE from Borg2011 to Borg2011b.
# 2026-03-10 16:58:35,603 - Changed @n for item EXXE8HEX from Chikovani1999 to Chikovani1999a.
# 2026-03-10 16:58:35,604 - Changed @n for item C2VVUC2M from Fleisch2011 to Fleisch2011b.
# 2026-03-10 16:58:35,605 - Changed @n for item 77QCKBGE from Gintsburg2008 to Gintsburg2008a.
# 2026-03-10 16:58:35,607 - Changed @n for item L2QSG9SL from Guerrero2016 to Guerrero2016a.
# 2026-03-10 16:58:35,607 - Changed @n for item YEFZ6KPD from Hassan2011 to Hassan2011a.
# 2026-03-10 16:58:35,609 - Changed @n for item 3LQK92SN from La_Rosa2019 to La_Rosa2019b.
# 2026-03-10 16:58:35,622 - Changed @n for item 78KPHRHB from Firănescu2016 to Firănescu2016b.
# 2026-03-10 16:58:35,624 - Changed @n for item YUNEWHDT from Heath1989 to Heath1989a.
# 2026-03-10 16:58:35,625 - Changed @n for item ZDL426LM from Holes2002 to Holes2000b.
# 2026-03-10 16:58:35,627 - Changed @n for item HVTXMC2N from Isaksson2000 to Isaksson2000b.
# 2026-03-10 16:58:35,632 - Changed @n for item 7IYEZ74H from Jarrah2019 to Jarrah2019b.
# 2026-03-10 16:58:35,634 - Changed @n for item PQIGU3PQ from Kaye1972 to Kaye1972a.
# 2026-03-10 16:58:35,635 - Changed @n for item 58EDFL56 from Kaye1997 to Kaye1997b.
# 2026-03-10 16:58:35,639 - Changed @n for item 9R6P5XIK from Hassan2016 to Hassan2016a.
# 2026-03-10 16:58:35,642 - Changed @n for item 7TANDEKW from Hary1996 to Hary1996b.
# 2026-03-10 16:58:35,643 - Changed @n for item D44UEG6F from Eid1995 to Eid1995b.
# 2026-03-10 16:58:35,645 - Changed @n for item 8LZVDIN9 from Khan2018 to Khan2018b.
# 2026-03-10 16:58:35,646 - Changed @n for item RCMKRF2U from Kenstowicz1983 to Kenstowicz1983b.
# 2026-03-10 16:58:35,648 - Changed @n for item M5TLIKSC from Kenstowicz1980b to Kenstowicz1980c.
# 2026-03-10 16:58:35,650 - Changed @n for item QFC6TJSQ from Kaye1993 to Kaye1993b.
# 2026-03-10 16:58:35,651 - Changed @n for item CDAU9HMK from Hallman2016 to Hallman2016a.
# 2026-03-10 16:58:35,653 - Changed @n for item XXXKBL4M from Halloun2008 to Halloun2008b.
# 2026-03-10 16:58:35,655 - Changed @n for item KF8CAXYX from Gudme1938 to Gudme1938b.
# 2026-03-10 16:58:35,656 - Changed @n for item S638HUG9 from Geva-Kleinberger2005 to Geva-Kleinberger2005a.
# 2026-03-10 16:58:35,658 - Changed @n for item J8L9XEK2 from Falchetta2024 to Falchetta2024b.
# 2026-03-10 16:58:35,659 - Changed @n for item LM78LHLW from Eid1992 to Eid1992b.
# 2026-03-10 16:58:35,660 - Changed @n for item NUAZVIVW from Rouchdy_Aleya2002 to Rouchdy_Aleya2002c.
# 2026-03-10 16:58:35,662 - Changed @n for item 6AQ88S5S from De_Jong2007 to De_Jong2007a.
# 2026-03-10 16:58:35,664 - Changed @n for item FUWPTPV9 from D_Anna2017 to D_Anna2017a.
# 2026-03-10 16:58:35,665 - Changed @n for item EN55PMI6 from Haddad2016 to Haddad2016c.
# 2026-03-10 16:58:35,666 - Changed @n for item 9YDLJZFL from Rosenbaum2000 to Rosenbaum2000a.
# 2026-03-10 16:58:35,667 - Changed @n for item Z3WICF47 from Prochazka1988 to Prochazka1988a.
# 2026-03-10 16:58:35,669 - Changed @n for item YRQNII86 from Procházka2009 to Procházka2009b.
# 2026-03-10 16:58:35,674 - Changed @n for item 7DMUS8ZC from Holes1984 to Holes1984a.
# 2026-03-10 16:58:35,676 - Changed @n for item QJ9G7A2S from Holes1983 to Holes1983b.
# 2026-03-10 16:58:35,679 - Changed @n for item MW9B4GIQ from Eades2009 to Eades2009b.
# 2026-03-10 16:58:35,681 - Changed @n for item 32X6BB45 from Dickins2011 to Dickins2011a.
# 2026-03-10 16:58:35,683 - Changed @n for item MG5RF7AF from Singer1958 to Singer1958c.
# 2026-03-10 16:58:35,684 - Changed @n for item ETRQBIKT from Singer1980 to Singer1980a.
# 2026-03-10 16:58:35,687 - Changed @n for item RMZWV2WX from Kilani-Schoch1986 to Kilani-Schoch1986b.
# 2026-03-10 16:58:35,688 - Changed @n for item HC5TLP34 from Jastrow1984 to Jastrow1984a.
# 2026-03-10 16:58:35,689 - Changed @n for item EGHYA4K7 from Jastrow1980a to Jastrow1980d.
# 2026-03-10 16:58:35,690 - Changed @n for item WAXREF6S from Jastrow2005 to Jastrow2005b.
# 2026-03-10 16:58:35,691 - Changed @n for item V58AQ2WK from Jastrow2004a to Jastrow2004c.
# 2026-03-10 16:58:35,692 - Changed @n for item WMLQRQCW from Jastrow2001 to Jastrow2001a.
# 2026-03-10 16:58:35,693 - Changed @n for item FU3PZVEZ from Jastrow1995 to Jastrow1995a.
# 2026-03-10 16:58:35,695 - Changed @n for item 96PMS2LM from Jastrow1991 to Jastrow1991a.
# 2026-03-10 16:58:35,696 - Changed @n for item G4XZ2V85 from Jastrow1989 to Jastrow1989b.
# 2026-03-10 16:58:35,697 - Changed @n for item 45UH6R6I from Jastrow1983 to Jastrow1983b.
# 2026-03-10 16:58:35,698 - Changed @n for item NA7NJIAN from Jastrow1982a to Jastrow1982b.
# 2026-03-10 16:58:35,699 - Changed @n for item L8PIXLID from Jastrow1982b to Jastrow1982a.
# 2026-03-10 16:58:35,700 - Changed @n for item HCZBFLLT from Jastrow1978 to Jastrow1978a.
# 2026-03-10 16:58:35,701 - Changed @n for item NW7S2ZHC from Jastrow1977a to Jastrow1977b.
# 2026-03-10 16:58:35,702 - Changed @n for item DXPR99F3 from Jastrow1977b to Jastrow1977a.
# 2026-03-10 16:58:35,703 - Changed @n for item CJLMX4TH from Jastrow1973 to Jastrow1973b.
# 2026-03-10 16:58:35,708 - Changed @n for item JJ5QE53Q from Littmann1950a to Littmann1950b.
# 2026-03-10 16:58:35,709 - Changed @n for item 2939DDX4 from Littmann1950b to Littmann1950a.
# 2026-03-10 16:58:35,711 - Changed @n for item GYRE7PRP from Miller2005 to Miller2005b.
# 2026-03-10 16:58:35,711 - Changed @n for item V9CAWXD3 from Miller1991 to Miller1991b.
# 2026-03-10 16:58:35,712 - Changed @n for item B4QT4YNL from Prokosch1983a to Prokosch1983b.
# 2026-03-10 16:58:35,713 - Changed @n for item 5J5GR8QZ from Prokosch1983b to Prokosch1983a.
# 2026-03-10 16:58:35,714 - Changed @n for item IXIJRVEE from Ritt-Benmimoun2011 to Ritt-Benmimoun2011a.
# 2026-03-10 16:58:35,715 - Changed @n for item S2JYKD9E from Ritt-Benmimoun2007 to Ritt-Benmimoun2007b.
# 2026-03-10 16:58:35,716 - Changed @n for item X6VBE97S from Kallas2000 to Kallas2000b.
# 2026-03-10 16:58:35,717 - Changed @n for item UBBPABH2 from Chaâbane1996 to Chaâbane1996a.
# 2026-03-10 16:58:35,718 - Changed @n for item 7J2QGGE3 from Caubet2004a to Caubet2004d.
# 2026-03-10 16:58:35,719 - Changed @n for item LQ3NTRJM from Caubet2005 to Caubet2005a.
# 2026-03-10 16:58:35,720 - Changed @n for item KBS3IGCI from Caubet2004b to Caubet2004c.
# 2026-03-10 16:58:35,721 - Changed @n for item V22ERHLT from Caubet2003 to Caubet2003b.
# 2026-03-10 16:58:35,723 - Changed @n for item SWWUVHLI from Bennis2001 to Bennis2001a.
# 2026-03-10 16:58:35,724 - Changed @n for item VTCM22NF from Baccouche2004 to Baccouche2004a.
# 2026-03-10 16:58:35,728 - Changed @n for item EX5HKLMG from Thay_Thay_Rhozali2000 to Thay_Thay_Rhozali2000b.
# 2026-03-10 16:58:35,729 - Changed @n for item U67UQI82 from Saada1966 to Saada1966a.
# 2026-03-10 16:58:35,731 - Changed @n for item JXSRMBDR from Said2006 to Said2006b.
# 2026-03-10 16:58:35,731 - Changed @n for item BWN2J75H from Vanhove1994 to Vanhove1994c.
# 2026-03-10 16:58:35,732 - Changed @n for item 9V5EI46E from Simeone-Senelle2002 to Simeone-Senelle2002b.
# 2026-03-10 16:58:35,733 - Changed @n for item TDAJ2QVD from Singer1980 to Singer1980b.
# 2026-03-10 16:58:35,734 - Changed @n for item BPX2Q5D6 from Moscoso2002 to Moscoso2002a.
# 2026-03-10 16:58:35,735 - Changed @n for item HKMCP9UC from Procházka2002 to Procházka2002d.
# 2026-03-10 16:58:35,736 - Changed @n for item TJCF9NH4 from Lahdo2009 to Lahdo2009b.
# 2026-03-10 16:58:35,737 - Changed @n for item KQDDBTFD from Naïm2011 to Naïm2011a.
# 2026-03-10 16:58:35,737 - Changed @n for item T8EGSTSI from Moscoso_García2003 to Moscoso_García2003a.
# 2026-03-10 16:58:35,739 - Changed @n for item N3DHG7H6 from Holes2018 to Holes2018b.
# 2026-03-10 16:58:35,741 - Changed @n for item R8D3MXFD from Kaye2007 to Kaye2007a.
# 2026-03-10 16:58:35,742 - Changed @n for item 7G84Y7LD from Manfredi2014 to Manfredi2014b.
# 2026-03-10 16:58:35,744 - Changed @n for item QI92THQS from Holes2002 to Holes2002b.
# 2026-03-10 16:58:35,746 - Changed @n for item RQB22XNX from Rouchdy_Aleya2002 to Rouchdy_Aleya2002a.
# 2026-03-10 16:58:35,747 - Changed @n for item NX9ENK4D from Kheshaifaty1993 to Kheshaifaty1993a.
# 2026-03-10 16:58:35,747 - Changed @n for item LI4Y9JEW from Lafkioui2013 to Lafkioui2013b.
# 2026-03-10 16:58:35,748 - Changed @n for item RHP79RAX from Magidow2013 to Magidow2013b.
# 2026-03-10 16:58:35,749 - Changed @n for item VNM5HTCK from Broselow2011 to Broselow2011e.
# 2026-03-10 16:58:35,749 - Changed @n for item 7CSLTHKS from Ferguson1997a to Ferguson1997f.
# 2026-03-10 16:58:35,750 - Changed @n for item DKSEW3HU from Geva-Kleinberger2017a to Geva-Kleinberger2017c.
# 2026-03-10 16:58:35,751 - Changed @n for item CB5GNVXS from Holes2007 to Holes2007c.
# 2026-03-10 16:58:35,752 - Changed @n for item IJWVACK6 from Isaksson2002 to Isaksson2002a.
# 2026-03-10 16:58:35,753 - Changed @n for item FIHZRQQE from Jastrow2004 to Jastrow2004a.
# 2026-03-10 16:58:35,754 - Changed @n for item E946WIXS from Haddad2016 to Haddad2016b.
# 2026-03-10 16:58:35,754 - Changed @n for item ITHBB7KV from Harrell1966 to Harrell1966b.
# 2026-03-10 16:58:35,755 - Changed @n for item 86LHF9E7 from Dallaji2017 to Dallaji2017a.
# 2026-03-10 16:58:35,756 - Changed @n for item 2F4KCSVL from Geva-Kleinberger2004 to Geva-Kleinberger2004c.
# 2026-03-10 16:58:35,757 - Changed @n for item 5S7W8ILV from Geva-Kleinberger2017b to Geva-Kleinberger2017a.
# 2026-03-10 16:58:35,758 - Changed @n for item QXK2F3NZ from Eisele1990 to Eisele1990b.
# 2026-03-10 16:58:35,759 - Changed @n for item HK5IP32R from Ferguson1997b to Ferguson1997a.
# 2026-03-10 16:58:35,760 - Changed @n for item 43BJKC2T from Ferguson1997c to Ferguson1997e.
# 2026-03-10 16:58:35,760 - Changed @n for item ARYVMACS from Corriente1994 to Corriente1994a.
# 2026-03-10 16:58:35,762 - Changed @n for item I7LKXJU2 from Farghal1995 to Farghal1995c.
# 2026-03-10 16:58:35,762 - Changed @n for item 8G9WW4QN from Firănescu2016 to Firănescu2016a.
# 2026-03-10 16:58:35,763 - Changed @n for item 7EIJU3ST from Geva-Kleinberger2002 to Geva-Kleinberger2002b.
# 2026-03-10 16:58:35,764 - Changed @n for item NT8DMJMK from Caubet2008 to Caubet2008a.
# 2026-03-10 16:58:35,765 - Changed @n for item 3FRIBJ53 from Corriente1994 to Corriente1994c.
# 2026-03-10 16:58:35,766 - Changed @n for item 7L8K66CL from Caubet2001 to Caubet2001c.
# 2026-03-10 16:58:35,767 - Changed @n for item AC8LJ9DV from Corriente1989 to Corriente1989b.
# 2026-03-10 16:58:35,769 - Changed @n for item WWURN579 from De_Jong1996a to De_Jong1996b.
# 2026-03-10 16:58:35,773 - Changed @n for item L7HN6K7L from De_Jong1996b to De_Jong1996a.
# 2026-03-10 16:58:35,775 - Changed @n for item RMMUPYVP from Eid1992 to Eid1992c.
# 2026-03-10 16:58:35,777 - Changed @n for item SN3S5UVZ from Eksell1984a to Eksell1984b.
# 2026-03-10 16:58:35,778 - Changed @n for item DFPQ47DP from Eksell1984b to Eksell1984a.
# 2026-03-10 16:58:35,779 - Changed @n for item CBT538U2 from Holes2013 to Holes2013b.
# 2026-03-10 16:58:35,780 - Changed @n for item UCVSRG6K from Holes2007a to Holes2007d.
# 2026-03-10 16:58:35,780 - Changed @n for item NP9J9EGT from Holes2006 to Holes2006a.
# 2026-03-10 16:58:35,781 - Changed @n for item 5F9K48FG from Holes2005 to Holes2005d.
# 2026-03-10 16:58:35,781 - Changed @n for item JCGM35IW from Holes2007b to Holes2007a.
# 2026-03-10 16:58:35,782 - Changed @n for item 5L9TFM5Z from Ingham2009 to Ingham2009b.
# 2026-03-10 16:58:35,783 - Changed @n for item HZ6C9U3G from Iraqui-Sinaceur2002 to Iraqui-Sinaceur2002b.
# 2026-03-10 16:58:35,784 - Changed @n for item NMU68KGA from Jastrow1989 to Jastrow1989a.
# 2026-03-10 16:58:35,784 - Changed @n for item HHM534A2 from Kaye1972 to Kaye1972b.
# 2026-03-10 16:58:35,785 - Changed @n for item W2H389WA from Kaye1994 to Kaye1994b.
# 2026-03-10 16:58:35,786 - Changed @n for item JSJVRA3V from Kaye1991a to Kaye1991b.
# 2026-03-10 16:58:35,787 - Changed @n for item NR6KKMJ2 from Kaye1991b to Kaye1991a.
# 2026-03-10 16:58:35,788 - Changed @n for item FFU89ZJW from Kaye1986 to Kaye1986b.
# 2026-03-10 16:58:35,789 - Changed @n for item TYXFP9LU from Procházka2008 to Procházka2008b.
# 2026-03-10 16:58:35,790 - Changed @n for item J3B58674 from Owens1998 to Owens1998b.
# 2026-03-10 16:58:35,791 - Changed @n for item WA6RJ7LH from Ritt-Benmimoun2022 to Ritt-Benmimoun2022a.
# 2026-03-10 16:58:35,795 - Changed @n for item 8EWW7DUY from Ritt-Benmimoun2023 to Ritt-Benmimoun2023b.
# 2026-03-10 16:58:35,796 - Changed @n for item 2VN5DMM9 from Rosenhouse1995 to Rosenhouse1995c.
# 2026-03-10 16:58:35,797 - Changed @n for item 4T6E55H9 from Rouchdy2002 to Rouchdy2002b.
# 2026-03-10 16:58:35,798 - Changed @n for item DP88I8IR from Mughazy2003 to Mughazy2003b.
# 2026-03-10 16:58:35,799 - Changed @n for item QB8QGRV4 from Nakao2016 to Nakao2016b.
# 2026-03-10 16:58:35,800 - Changed @n for item 8CH8GC6P from Nakao2016 to Nakao2016a.
# 2026-03-10 16:58:35,800 - Changed @n for item ZBQCLVXX from Rosenhouse1978 to Rosenhouse1978a.
# 2026-03-10 16:58:35,801 - Changed @n for item C6SWV5H9 from Ritt-Benmimoun2025 to Ritt-Benmimoun2025b.
# 2026-03-10 16:58:35,802 - Changed @n for item KZ8WZ5ER from Ritt-Benmimoun2024 to Ritt-Benmimoun2024b.
# 2026-03-10 16:58:35,803 - Changed @n for item VJ6NHD6X from Rouchdy_Aleya2002 to Rouchdy_Aleya2002b.
# 2026-03-10 16:58:35,804 - Changed @n for item JXGBYNFC from D_Anna2018 to D_Anna2018d.
# 2026-03-10 16:58:35,805 - Changed @n for item 9NFD6QJN from Ferguson1997 to Ferguson1997d.
# 2026-03-10 16:58:35,807 - Changed @n for item 9IV7ATAF from Geva-Kleinberger2017 to Geva-Kleinberger2017b.
# 2026-03-10 16:58:35,809 - Changed @n for item FEE5X8LZ from Harrell1965 to Harrell1965a.
# 2026-03-10 16:58:35,810 - Changed @n for item ZSTSY7NG from Holes2018 to Holes2018c.
# 2026-03-10 16:58:35,811 - Changed @n for item WBKXJQKI from Jastrow2011 to Jastrow2011b.
# 2026-03-10 16:58:35,812 - Changed @n for item PT7GHQVQ from de_Jong2013 to de_Jong2013f.
# 2026-03-10 16:58:35,814 - Changed @n for item FPI3TEN3 from Kenstowicz1980 to Kenstowicz1980b.
# 2026-03-10 16:58:35,815 - Changed @n for item JXG9ALJK from Mazraani1995 to Mazraani1995b.
# 2026-03-10 16:58:35,818 - Changed @n for item G34IUYYY from Mejdell2006 to Mejdell2006a.
# 2026-03-10 16:58:35,819 - Changed @n for item XEBEEZ4S from Miller2002 to Miller2002a.
# 2026-03-10 16:58:35,820 - Changed @n for item R798NIYS from Mughazy2003 to Mughazy2003a.
# 2026-03-10 16:58:35,821 - Changed @n for item VHTMWE3G from Procházka2002 to Procházka2002a.
# 2026-03-10 16:58:35,822 - Changed @n for item RSQHVS4C from Ritt-Benmimoun2022 to Ritt-Benmimoun2022b.
# 2026-03-10 16:58:35,822 - Changed @n for item XEZAEM3H from Piamenta1990 to Piamenta1990a.
# 2026-03-10 16:58:35,823 - Changed @n for item K83VBSJP from Prochazka1988 to Prochazka1988b.
# 2026-03-10 16:58:35,824 - Changed @n for item EAYH76UY from Ritt-Benmimoun2009 to Ritt-Benmimoun2009a.
# 2026-03-10 16:58:35,826 - Changed @n for item Z5PAE9GX from Lahdo2009 to Lahdo2009a.
# 2026-03-10 16:58:35,826 - Changed @n for item JM4EGMCH from Lentin2006 to Lentin2006c.
# 2026-03-10 16:58:35,827 - Changed @n for item TCPEGUUH from Mansour2002 to Mansour2002b.
# 2026-03-10 16:58:35,829 - Changed @n for item 28E4TE55 from Piamenta1991 to Piamenta1991b.
# 2026-03-10 16:58:35,830 - Changed @n for item GQPAJDNV from Procházka2014 to Procházka2014b.
# 2026-03-10 16:58:35,830 - Changed @n for item 9AT3RLIF from Boucherit2016 to Boucherit2016a.
# 2026-03-10 16:58:35,831 - Changed @n for item RWWZW9M7 from Borg1994 to Borg1994c.
# 2026-03-10 16:58:35,832 - Changed @n for item U6Z6VZQA from Sawaie1994 to Sawaie1994b.
# 2026-03-10 16:58:35,832 - Changed @n for item MIJBIDQF from Caubet1991 to Caubet1991b.
# 2026-03-10 16:58:35,833 - Changed @n for item 44ISB3FI from Corriente1998 to Corriente1998a.
# 2026-03-10 16:58:35,834 - Changed @n for item NHCEQM94 from De_Blasio2019 to De_Blasio2019b.
# 2026-03-10 16:58:35,835 - Changed @n for item W7QR8SXL from Farghal1995 to Farghal1995a.
# 2026-03-10 16:58:35,836 - Changed @n for item 54QYU7PY from Halloun2008 to Halloun2008a.
# 2026-03-10 16:58:35,837 - Changed @n for item KW6MCJ72 from Hallman2018b to Hallman2018c.
# 2026-03-10 16:58:35,838 - Changed @n for item W94XTJUV from Holes1984 to Holes1984b.
# 2026-03-10 16:58:35,839 - Changed @n for item JENTTVA5 from Ingham1980 to Ingham1980b.
# 2026-03-10 16:58:35,840 - Changed @n for item TY2CS5PB from Bloch1971 to Bloch1971b.
# 2026-03-10 16:58:35,841 - Changed @n for item A5YWVGZI from Blau1968 to Blau1968b.
# 2026-03-10 16:58:35,841 - Changed @n for item IITBZHDJ from Blau1965 to Blau1965b.
# 2026-03-10 16:58:35,842 - Changed @n for item EUVRN8AA from Bettega2016 to Bettega2016b.
# 2026-03-10 16:58:35,847 - Changed @n for item 4JHKMHEL from Benhallam1995 to Benhallam1995b.
# 2026-03-10 16:58:35,849 - Changed @n for item ZHHJXEY4 from Benhallam1990 to Benhallam1990b.
# 2026-03-10 16:58:35,852 - Changed @n for item R5WTIK79 from Avram2016 to Avram2016a.
# 2026-03-10 16:58:35,854 - Changed @n for item R3V94MIW from Albader2016 to Albader2016b.
# 2026-03-10 16:58:35,865 - Changed @n for item WUJXJPD7 from Rouchdy_Aleya2002 to Rouchdy_Aleya2002h.
# 2026-03-10 16:58:35,866 - Changed @n for item N46L8DAQ from Al-Saqqaf2006 to Al-Saqqaf2006b.
# 2026-03-10 16:58:35,869 - Changed @n for item EKHDPGGP from Mion2017 to Mion2017a.
# 2026-03-10 16:58:35,870 - Changed @n for item TLWZ85HX from Miller2000 to Miller2000b.
# 2026-03-10 16:58:35,872 - Changed @n for item XTA6QTD8 from Owens2010 to Owens2010c.
# 2026-03-10 16:58:35,874 - Changed @n for item KGUNJXTJ from Owens2000 to Owens2000b.
# 2026-03-10 16:58:35,875 - Changed @n for item JX2JTP3W from Owens1998 to Owens1998a.
# 2026-03-10 16:58:35,878 - Changed @n for item 3LCCNA9T from Owens1993 to Owens1993d.
# 2026-03-10 16:58:35,880 - Changed @n for item R6UT3MN2 from Owens1991 to Owens1991a.
# 2026-03-10 16:58:35,882 - Changed @n for item NS5NNJB4 from Qafisheh1997 to Qafisheh1997a.
# 2026-03-10 16:58:35,883 - Changed @n for item 2V9L6GP4 from Qafisheh1996 to Qafisheh1996a.
# 2026-03-10 16:58:35,885 - Changed @n for item AD4G9WPR from Ritt-Benmimoun2012 to Ritt-Benmimoun2012b.
# 2026-03-10 16:58:35,887 - Changed @n for item BJH76EVK from Ritt-Benmimoun2009 to Ritt-Benmimoun2009c.
# 2026-03-10 16:58:35,888 - Changed @n for item Z8SNVE3N from Ruiter2008 to Ruiter2008a.
# 2026-03-10 16:58:35,890 - Changed @n for item 7IK5LVCP from Rosenhouse2007 to Rosenhouse2007b.
# 2026-03-10 16:58:35,892 - Changed @n for item ESQZAJRJ from Salonen1980 to Salonen1980a.
# 2026-03-10 16:58:35,894 - Changed @n for item DBVEXYIT from Shachmon2013 to Shachmon2013c.
# 2026-03-10 16:58:35,895 - Changed @n for item EGAERXTT from Holes1996 to Holes1996b.
# 2026-03-10 16:58:35,896 - Changed @n for item 4VCHQJHL from Holes1995b to Holes1995c.
# 2026-03-10 16:58:35,901 - Changed @n for item QPHTGYNG from Kimary2011 to Kimary2011a.
# 2026-03-10 16:58:35,903 - Changed @n for item XT9VRT6K from Haddad2016 to Haddad2016h.
# 2026-03-10 16:58:35,905 - Changed @n for item WVMWKH6D from Louis2008a to Louis2008b.
# 2026-03-10 16:58:35,906 - Changed @n for item 54BB99GF from Louis2008b to Louis2008c.
# 2026-03-10 16:58:35,907 - Changed @n for item SIDXEU22 from Louis2008c to Louis2008a.
# 2026-03-10 16:58:35,909 - Changed @n for item 89YDUUBN from Nishio1995 to Nishio1995b.
# 2026-03-10 16:58:35,911 - Changed @n for item NNNPKJH6 from Nydell1990a to Nydell1990b.
# 2026-03-10 16:58:35,918 - Changed @n for item SV7WPUIR from Nydell1990b to Nydell1990a.
# 2026-03-10 16:58:35,919 - Changed @n for item BSV4XR3K from Ould_Mohamed_Baba2006 to Ould_Mohamed_Baba2006b.
# 2026-03-10 16:58:35,920 - Changed @n for item JXMADIIX from Owens1991a to Owens1991c.
# 2026-03-10 16:58:35,922 - Changed @n for item 6Z63AC8X from Owens1987 to Owens1987b.
# 2026-03-10 16:58:35,924 - Changed @n for item 4KBJ32LB from Owens2000 to Owens2000a.
# 2026-03-10 16:58:35,926 - Changed @n for item MMAH7BGI from Palva2004 to Palva2004a.
# 2026-03-10 16:58:35,928 - Changed @n for item WYI25YGZ from Palva1992 to Palva1992b.
# 2026-03-10 16:58:35,929 - Changed @n for item FX7G9IIQ from Palva1991 to Palva1991b.
# 2026-03-10 16:58:35,930 - Changed @n for item 3FVIA4A3 from Palva1984 to Palva1984b.
# 2026-03-10 16:58:35,931 - Changed @n for item K2ZVG66A from Owens2010a to Owens2010d.
# 2026-03-10 16:58:35,932 - Changed @n for item AEVJWPMA from Haak2003 to Haak2003b.
# 2026-03-10 16:58:35,933 - Changed @n for item SFAWITQA from Owens2010b to Owens2010a.
# 2026-03-10 16:58:35,934 - Changed @n for item 7LNWWID3 from Owens2018 to Owens2018a.
# 2026-03-10 16:58:35,935 - Changed @n for item N528TGE5 from Owens2019 to Owens2019a.
# 2026-03-10 16:58:35,936 - Changed @n for item IJRXQEIR from Palva1969 to Palva1969a.
# 2026-03-10 16:58:35,938 - Changed @n for item T238A89P from Sibony2019 to Sibony2019a.
# 2026-03-10 16:58:35,939 - Changed @n for item YV9CGWBZ from Talmoudi1984 to Talmoudi1984c.
# 2026-03-10 16:58:35,941 - Changed @n for item DFX7EXVU from Talmon2003 to Talmon2003a.
# 2026-03-10 16:58:35,942 - Changed @n for item HQWZXNVG from Talay2003 to Talay2003b.
# 2026-03-10 16:58:35,944 - Changed @n for item 38G69SUV from Talmon2001a to Talmon2001b.
# 2026-03-10 16:58:35,945 - Changed @n for item XJRWQS2S from Talmon2001b to Talmon2001a.
# 2026-03-10 16:58:35,946 - Changed @n for item G2KPGLTJ from Talmon2002 to Talmon2002b.
# 2026-03-10 16:58:35,947 - Changed @n for item KZGIVEJM from Dickins2007 to Dickins2007b.
# 2026-03-10 16:58:35,948 - Changed @n for item MAS54RHK from de_Jong2013 to de_Jong2013d.
# 2026-03-10 16:58:35,949 - Changed @n for item 6MYWQIJT from De_Jong2007 to De_Jong2007b.
# 2026-03-10 16:58:35,950 - Changed @n for item SDNWNF5I from Borg1994 to Borg1994b.
# 2026-03-10 16:58:35,951 - Changed @n for item RK4FV4ZA from Boumans2000 to Boumans2000b.
# 2026-03-10 16:58:35,952 - Changed @n for item X72VH6CJ from Boumans2002 to Boumans2002a.
# 2026-03-10 16:58:35,953 - Changed @n for item ARB35VRV from Boucherit2016 to Boucherit2016b.
# 2026-03-10 16:58:35,954 - Changed @n for item HWND8DX4 from Aguadé2000 to Aguadé2000a.
# 2026-03-10 16:58:35,957 - Changed @n for item 83KURA8S from Aguadé1998 to Aguadé1998b.
# 2026-03-10 16:58:35,958 - Changed @n for item V5EF6JBZ from Akkuş2016 to Akkuş2016a.
# 2026-03-10 16:58:35,959 - Changed @n for item HRG23RGL from Aguadé2016 to Aguadé2016b.
# 2026-03-10 16:58:35,960 - Changed @n for item 9PSQT8VP from Aguadé2005 to Aguadé2005b.
# 2026-03-10 16:58:35,961 - Changed @n for item LVWETTC2 from Aguadé2002 to Aguadé2002a.
# 2026-03-10 16:58:35,963 - Changed @n for item LPS7XDE2 from Aguadé1999 to Aguadé1999a.
# 2026-03-10 16:58:35,963 - Changed @n for item 4SE4AB6H from La_Rosa2021 to La_Rosa2021b.
# 2026-03-10 16:58:35,964 - Changed @n for item MPDJF6H3 from D_Anna2018 to D_Anna2018b.
# 2026-03-10 16:58:35,965 - Changed @n for item 7TMLL9NZ from Behnstedt1994 to Behnstedt1994b.
# 2026-03-10 16:58:35,966 - Changed @n for item 4YZ23XLB from Leitner2022 to Leitner2022a.
# 2026-03-10 16:58:35,967 - Changed @n for item RKDZJSQL from Vanhove1994 to Vanhove1994b.
# 2026-03-10 16:58:35,970 - Changed @n for item P3W9JKXE from Talmon2003 to Talmon2003b.
# 2026-03-10 16:58:35,971 - Changed @n for item TB4VYI4Y from Sawaie1994 to Sawaie1994a.
# 2026-03-10 16:58:35,976 - Changed @n for item 2UFRJTYT from Miller2003 to Miller2003a.
# 2026-03-10 16:58:35,978 - Changed @n for item 6GN4Q3NI from Langone2003 to Langone2003b.
# 2026-03-10 16:58:35,979 - Changed @n for item 2M9FC8AR from Lentin2004 to Lentin2004b.
# 2026-03-10 16:58:36,297 - Changed @n for item XRGSH97K from Luffin2004 to Luffin2004b.
# 2026-03-10 16:58:36,299 - Changed @n for item 5S4HM95V from Sinaceur1994 to Sinaceur1994a.
# 2026-03-10 16:58:36,300 - Changed @n for item KEQPPZJQ from Simeone-Senelle2002 to Simeone-Senelle2002a.
# 2026-03-10 16:58:36,301 - Changed @n for item YFHZMXI4 from Said2006 to Said2006a.
# 2026-03-10 16:58:36,301 - Changed @n for item GT8GAQT3 from Konrad_Adenauer_Stiftung1995 to Konrad_Adenauer_Stiftung1995a.
# 2026-03-10 16:58:36,302 - Changed @n for item JKZDRLTL from Kilani-Schoch1986 to Kilani-Schoch1986a.
# 2026-03-10 16:58:36,303 - Changed @n for item JV79C5XK from Germanos2015 to Germanos2015b.
# 2026-03-10 16:58:36,304 - Changed @n for item RNYIYEZK from Procházka2000 to Procházka2000b.
# 2026-03-10 16:58:36,305 - Changed @n for item ZIM78N6Z from Ruiter2009a to Ruiter2009b.
# 2026-03-10 16:58:36,306 - Changed @n for item B5XP66C2 from Ruiter2009b to Ruiter2009a.
# 2026-03-10 16:58:36,307 - Changed @n for item 7NPU9S7J from Guerrero2019 to Guerrero2019b.
# 2026-03-10 16:58:36,308 - Changed @n for item RC2PABIL from Isaksson2000 to Isaksson2000a.
# 2026-03-10 16:58:36,308 - Changed @n for item T4MKZVLE from Hilili1987 to Hilili1987b.
# 2026-03-10 16:58:36,310 - Changed @n for item PIQW3WII from Holes2008 to Holes2008a.
# 2026-03-10 16:58:36,311 - Changed @n for item 6WZ24K6M from Idrissi2003 to Idrissi2003a.
# 2026-03-10 16:58:36,312 - Changed @n for item UWCCMQDV from Idrissi1987a to Idrissi1987b.
# 2026-03-10 16:58:36,312 - Changed @n for item ES6FLF7K from Idrissi1987b to Idrissi1987a.
# 2026-03-10 16:58:36,313 - Changed @n for item 226QH529 from Ingham2004 to Ingham2004b.
# 2026-03-10 16:58:36,314 - Changed @n for item ISFHUIYP from Kaye1986 to Kaye1986a.
# 2026-03-10 16:58:36,314 - Changed @n for item 8H6FLIJG from Kallas2000 to Kallas2000a.
# 2026-03-10 16:58:36,315 - Changed @n for item BF7QVM6P from Fleisch1974a to Fleisch1974b.
# 2026-03-10 16:58:36,316 - Changed @n for item J7Y8RBXH from Ferrando2000 to Ferrando2000b.
# 2026-03-10 16:58:36,317 - Changed @n for item LCVIS4X2 from De_Jong2000 to De_Jong2000a.
# 2026-03-10 16:58:36,319 - Changed @n for item ZATQJVPJ from Maas2000 to Maas2000d.
# 2026-03-10 16:58:36,326 - Changed @n for item VVZMLQYB from Marçais1977 to Marçais1977a.
# 2026-03-10 16:58:36,328 - Changed @n for item A4BCW2LJ from Mejri2006 to Mejri2006a.
# 2026-03-10 16:58:36,333 - Changed @n for item 56LAPB2W from Ould_Mohamed_Baba1998 to Ould_Mohamed_Baba1998c.
# 2026-03-10 16:58:36,336 - Changed @n for item LXD4F8P6 from Mion2014 to Mion2014a.
# 2026-03-10 16:58:36,338 - Changed @n for item DQSBVFYG from Fleisch1974b to Fleisch1974a.
# 2026-03-10 16:58:36,339 - Changed @n for item QI7EZGJZ from Fleisch1974c to Fleisch1974d.
# 2026-03-10 16:58:36,341 - Changed @n for item WRZRBD9P from De_Jong1996 to De_Jong1996c.
# 2026-03-10 16:58:36,342 - Changed @n for item VKRPF5BF from Cohen1964b to Cohen1964c.
# 2026-03-10 16:58:36,344 - Changed @n for item JB86MHPY from Chetrit1980 to Chetrit1980a.
# 2026-03-10 16:58:36,347 - Changed @n for item TZV25Z9I from Caubet1985a to Caubet1985b.
# 2026-03-10 16:58:36,348 - Changed @n for item D39NK9GI from Ould_Mohamed_Baba2001 to Ould_Mohamed_Baba2001a.
# 2026-03-10 16:58:36,349 - Changed @n for item LRHBHXRV from Ould_Mohamed_Baba2008 to Ould_Mohamed_Baba2008b.
# 2026-03-10 16:58:36,350 - Changed @n for item WAFPRQTN from Caubet2000a to Caubet2000b.
# 2026-03-10 16:58:36,352 - Changed @n for item B9QMMN3U from Caubet1985b to Caubet1985a.
# 2026-03-10 16:58:36,357 - Changed @n for item DSCCXVCR from Chaâbane1996 to Chaâbane1996b.
# 2026-03-10 16:58:36,360 - Changed @n for item CFKUPFKR from Caubet1996a to Caubet1996c.
# 2026-03-10 16:58:36,362 - Changed @n for item 56UTPC29 from Caubet2003 to Caubet2003c.
# 2026-03-10 16:58:36,365 - Changed @n for item D6BTIQPM from Caubet1996b to Caubet1996a.
# 2026-03-10 16:58:36,367 - Changed @n for item AIMIVYQK from Caubet2000b to Caubet2000c.
# 2026-03-10 16:58:36,370 - Changed @n for item X4ESP49B from Boris1951 to Boris1951a.
# 2026-03-10 16:58:36,371 - Changed @n for item DDXUHXWD from Boucherit1987 to Boucherit1987a.
# 2026-03-10 16:58:36,373 - Changed @n for item IRHPIM5R from Brunot1950 to Brunot1950b.
# 2026-03-10 16:58:36,376 - Changed @n for item 4J5P99TR from Benkirane1982a to Benkirane1982b.
# 2026-03-10 16:58:36,377 - Changed @n for item 7RGHYDUC from Benkirane1982b to Benkirane1982a.
# 2026-03-10 16:58:36,379 - Changed @n for item W29EP6D6 from Rosenhouse1995 to Rosenhouse1995b.
# 2026-03-10 16:58:36,380 - Changed @n for item YE8JURBC from Procházka1995 to Procházka1995b.
# 2026-03-10 16:58:36,381 - Changed @n for item QCTP8KHL from Ould_Mohamed_Baba2003 to Ould_Mohamed_Baba2003c.
# 2026-03-10 16:58:36,382 - Changed @n for item ANAW285X from Miller1987a to Miller1987b.
# 2026-03-10 16:58:36,383 - Changed @n for item C6YEWTF2 from Miller1987b to Miller1987a.
# 2026-03-10 16:58:36,384 - Changed @n for item 2TILWZED from Lévy1998 to Lévy1998a.
# 2026-03-10 16:58:36,385 - Changed @n for item J8IFLP6N from Lévy1996 to Lévy1996a.
# 2026-03-10 16:58:36,386 - Changed @n for item BQ9L8YBX from Lentin1996 to Lentin1996a.
# 2026-03-10 16:58:36,387 - Changed @n for item RSKAVWEG from Lentin1995 to Lentin1995a.
# 2026-03-10 16:58:36,388 - Changed @n for item SP2LACSH from Caubet1996c to Caubet1996d.
# 2026-03-10 16:58:36,390 - Changed @n for item 9XRTIYLX from Caubet2000c to Caubet2000e.
# 2026-03-10 16:58:36,391 - Changed @n for item 7UJ4ZEEG from Caubet1992 to Caubet1992a.
# 2026-03-10 16:58:36,392 - Changed @n for item 4Z6G72AE from Mifsud1995 to Mifsud1995b.
# 2026-03-10 16:58:36,394 - Changed @n for item 9WU7BAZF from Messaoudi2003 to Messaoudi2003a.
# 2026-03-10 16:58:36,396 - Changed @n for item SQ9ELGFN from Messaoudi1998 to Messaoudi1998b.
# 2026-03-10 16:58:36,399 - Changed @n for item 2JRDI9H5 from Naddari2022 to Naddari2022b.
# 2026-03-10 16:58:36,400 - Changed @n for item VBCAJFB3 from Naïm2006 to Naïm2006a.
# 2026-03-10 16:58:36,402 - Changed @n for item ECP3ZE6D from Quitout1999 to Quitout1999b.
# 2026-03-10 16:58:36,404 - Changed @n for item VMYUEL8W from Pereira2003 to Pereira2003a.
# 2026-03-10 16:58:36,406 - Changed @n for item PKKJKS25 from Quitout2001 to Quitout2001b.
# 2026-03-10 16:58:36,407 - Changed @n for item P54BBL54 from Grigore2019 to Grigore2019b.
# 2026-03-10 16:58:36,409 - Changed @n for item TRAIAZ97 from Grigore2016 to Grigore2016b.
# 2026-03-10 16:58:36,411 - Changed @n for item L3ST7MAE from Grigore2011 to Grigore2011b.
# 2026-03-10 16:58:36,414 - Changed @n for item 5T9DJGTF from Grigore2008a to Grigore2008b.
# 2026-03-10 16:58:36,416 - Changed @n for item 7VFNSCLB from Grigore2008b to Grigore2008a.
# 2026-03-10 16:58:36,419 - Changed @n for item 8ZVPSTF2 from Grigore2006 to Grigore2006b.
# 2026-03-10 16:58:36,421 - Changed @n for item JZEYAHP3 from Grand_Henry1976 to Grand_Henry1976a.
# 2026-03-10 16:58:36,423 - Changed @n for item BHKXKTY4 from Grand_Henry1991 to Grand_Henry1991b.
# 2026-03-10 16:58:36,424 - Changed @n for item C742PGCT from Cifoletti2006 to Cifoletti2006b.
# 2026-03-10 16:58:36,426 - Changed @n for item KCIKGWM9 from Colin1960 to Colin1960b.
# 2026-03-10 16:58:36,427 - Changed @n for item NTCCFAJ5 from Colin1957 to Colin1957b.
# 2026-03-10 16:58:36,429 - Changed @n for item IIBHE5TL from Cohen1973 to Cohen1973b.
# 2026-03-10 16:58:36,430 - Changed @n for item LYZ7D9MJ from Cohen1970a to Cohen1970e.
# 2026-03-10 16:58:36,431 - Changed @n for item B5XFXR9X from Cohen1970b to Cohen1970d.
# 2026-03-10 16:58:36,433 - Changed @n for item LSVIYV79 from Cohen1970c to Cohen1970b.
# 2026-03-10 16:58:36,434 - Changed @n for item JKJB6ZMD from Cohen1965 to Cohen1965b.
# 2026-03-10 16:58:36,435 - Changed @n for item PV4ZU6UQ from Cohen1964 to Cohen1964b.
# 2026-03-10 16:58:36,436 - Changed @n for item EII9BIGN from Cohen1979 to Cohen1979a.
# 2026-03-10 16:58:36,438 - Changed @n for item RR978J9X from Colin1953a to Colin1953b.
# 2026-03-10 16:58:36,440 - Changed @n for item 2JSYJV94 from Colin1953b to Colin1953a.
# 2026-03-10 16:58:36,442 - Changed @n for item E3WA5FD9 from Colin1948 to Colin1948a.
# 2026-03-10 16:58:36,443 - Changed @n for item IH7T9CWW from Colin1945a to Colin1945c.
# ...
# 2026-03-10 16:58:37,746 - Changed @n for item 9ZPCGWCY from Talmon2002 to Talmon2002a.
# 2026-03-10 16:58:37,747 - Changed @n for item I3QQ4ENH from Procházka2002 to Procházka2002b.
# 2026-03-10 16:58:37,748 - Changed @n for item HMMF39HQ from Arnold2006 to Arnold2006a.
# 2026-03-10 16:58:37,748 - Changed @n for item 4X55WQEN from Marçais1931 to Marçais1931a.
# 2026-03-10 16:58:37,749 - Changed @n for item ZSV29MT7 from Czapkiewicz1977 to Czapkiewicz1977a.
# 2026-03-10 16:58:37,750 - Changed @n for item XZT67CYS from Lévy1998 to Lévy1998b.
# 2026-03-10 16:58:37,751 - Changed @n for item P3AWT7HL from Pallottino2016 to Pallottino2016a.
# 2026-03-10 16:58:37,751 - Changed @n for item 57V5I4FK from Ritt-Benmimoun2017 to Ritt-Benmimoun2017b.
# 2026-03-10 16:58:37,752 - Changed @n for item XX37TEDV from Hassan2023 to Hassan2022a.
# 2026-03-10 16:58:37,753 - Changed @n for item H9B78EWW from Chikovani2007 to Chikovani2007a.
# 2026-03-10 16:58:37,755 - Changed @n for item ADWLVH4J from Chikovani1999 to Chikovani1999b.
# 2026-03-10 16:58:37,759 - Changed @n for item RNJVZ5ZY from Behnstedt1993 to Behnstedt1993b.
# 2026-03-10 16:58:37,760 - Changed @n for item RLWHIEMA from Lucas2020 to Lucas2020n.
# 2026-03-10 16:58:37,761 - Changed @n for item GLZJDZJ8 from Naïm2006 to Naïm2006b.
# 2026-03-10 16:58:37,762 - Changed @n for item M7UJPP23 from Durand1994 to Durand1994a.
# 2026-03-10 16:58:37,763 - Changed @n for item VHZ3ZJFP from Durand1995a to Durand1995b.
# 2026-03-10 16:58:37,763 - Changed @n for item 8PDALG3N from Durand1995b to Durand1995c.
# 2026-03-10 16:58:37,765 - Changed @n for item RTU42GAI from Miller2020 to Miller2020b.
# 2026-03-10 16:58:37,766 - Changed @n for item YHRMX2NB from Taine-Cheikh2020 to Taine-Cheikh2020b.
# 2026-03-10 16:58:37,767 - Changed @n for item N8LWJJUV from Caubet2000 to Caubet2000d.
# 2026-03-10 16:58:37,768 - Changed @n for item 7AXF84RI from Zafrani1988 to Zafrani1988a.
# 2026-03-10 16:58:37,779 - Changed @n for item 2YNKCJG6 from Taine-Cheikh1989 to Taine-Cheikh1989c.
# 2026-03-10 16:58:37,785 - Changed @n for item BQDY7XC9 from Arnold2010 to Arnold2010a.
# 2026-03-10 16:58:37,786 - Changed @n for item TMNXE5WZ from Seeger2009a to Seeger2009d.
# 2026-03-10 16:58:37,788 - Changed @n for item Z8G4VXNC from Procházka2006 to Procházka2006b.
# 2026-03-10 16:58:37,789 - Changed @n for item I88629Z5 from Seeger2022 to Seeger2022b.
# 2026-03-10 16:58:37,791 - Changed @n for item VWKRLHR9 from Seeger2009c to Seeger2009a.
# 2026-03-10 16:58:37,792 - Changed @n for item 7EUR8W9Z from Behnstedt2009 to Behnstedt2009b.
# 2026-03-10 16:58:37,793 - Changed @n for item PPLUTZ4Z from Roth1995 to Roth1995c.
# 2026-03-10 16:58:37,795 - Changed @n for item 6TX34JCH from Geva-Kleinberger2002 to Geva-Kleinberger2002a.
# 2026-03-10 16:58:37,800 - Changed @n for item 8JJ8RI7B from Hassan2022 to Hassan2022b.
# 2026-03-10 16:58:37,802 - Changed @n for item 8PLA4F7L from Holes2007 to Holes2007b.
# 2026-03-10 16:58:37,804 - Changed @n for item EYYYMGMV from Hassan2019a to Hassan2019b.
# 2026-03-10 16:58:37,808 - Changed @n for item 3GZAMDR3 from Diem1974 to Diem1974a.
# 2026-03-10 16:58:37,810 - Changed @n for item MQ8WL38L from Leitner2021 to Leitner2021b.
# 2026-03-10 16:58:37,812 - Changed @n for item X27P6FN9 from Hassan2021 to Hassan2021a.
# 2026-03-10 16:58:37,814 - Changed @n for item L3RS3EW3 from Hassan2017 to Hassan2017b.
# 2026-03-10 16:58:37,817 - Changed @n for item B2IU9R3N from Hassan2016a to Hassan2016c.
# 2026-03-10 16:58:37,819 - Changed @n for item 42DPMBBV from Hassan2019b to Hassan2019a.
# 2026-03-10 16:58:37,820 - Changed @n for item 8PI8NX3Y from Procházka1995 to Procházka1995c.
# 2026-03-10 16:58:37,821 - Changed @n for item G4IMBSK9 from Taine-Cheikh2020 to Taine-Cheikh2020a.
# 2026-03-10 16:58:37,824 - Changed @n for item E7BCUEFG from Jastrow1991 to Jastrow1991b.
# 2026-03-10 16:58:37,825 - Changed @n for item LGITZJAB from Behnstedt1992 to Behnstedt1992b.
# 2026-03-10 16:58:37,827 - Changed @n for item QNTUUHFW from Broselow2011a to Broselow2011c.
# 2026-03-10 16:58:37,834 - Changed @n for item W33JKAA9 from Moscoso1999 to Moscoso1999b.
# 2026-03-10 16:58:37,837 - Changed @n for item 48KMHNSI from Moscoso2003 to Moscoso2003c.
# 2026-03-10 16:58:37,840 - Changed @n for item 93DABKLD from Ingham1994 to Ingham1994e.
# 2026-03-10 16:58:37,841 - Changed @n for item VKTVHDB8 from Holes2004 to Holes2004b.
# 2026-03-10 16:58:37,843 - Changed @n for item 2MIYCKM3 from Eades2013 to Eades2013b.
# 2026-03-10 16:58:37,844 - Changed @n for item WQXHPEAN from Holes2008 to Holes2008b.
# 2026-03-10 16:58:37,846 - Changed @n for item LSDCZ4SZ from Behnstedt2017 to Behnstedt2017b.
# 2026-03-10 16:58:37,850 - Changed @n for item UE3HR6BX from Chikovani1999 to Chikovani1999c.
# 2026-03-10 16:58:37,853 - Changed @n for item E4FVCEXY from Chikovani2004 to Chikovani2004a.
# 2026-03-10 16:58:37,854 - Changed @n for item KQYEN6M7 from Chikovani2007 to Chikovani2007b.
# 2026-03-10 16:58:37,856 - Changed @n for item KM2D4DUH from Jastrow1990 to Jastrow1990a.
# 2026-03-10 16:58:37,858 - Changed @n for item 9GUTJ6LN from Broselow2011b to Broselow2011h.
# 2026-03-10 16:58:37,859 - Changed @n for item MRWBM7ME from Broselow2011c to Broselow2011i.
# 2026-03-10 16:58:37,862 - Changed @n for item T7ICZVDZ from Broselow2011d to Broselow2011g.
# 2026-03-10 16:58:37,864 - Changed @n for item VDJTT7N2 from Broselow2011e to Broselow2011f.
# 2026-03-10 16:58:37,866 - Changed @n for item 5D5EL6BF from Broselow2011f to Broselow2011b.
# 2026-03-10 16:58:37,868 - Changed @n for item PMWI5L2R from Broselow2011g to Broselow2011d.
# 2026-03-10 16:58:37,870 - Changed @n for item NKJYMNDU from Owens2010 to Owens2010b.
# 2026-03-10 16:58:37,872 - Changed @n for item LLS3FCM8 from Holes2010 to Holes2010b.
# 2026-03-10 16:58:37,873 - Changed @n for item FIFIPYS9 from Khan2018 to Khan2018a.
# 2026-03-10 16:58:37,875 - Changed @n for item 969VGCRZ from Lucas2020a to Lucas2020k.
# 2026-03-10 16:58:37,878 - Changed @n for item 9QJ2HXRF from Lucas2020b to Lucas2020u.
# 2026-03-10 16:58:37,880 - Changed @n for item AQXGA889 from Lucas2020c to Lucas2020j.
# 2026-03-10 16:58:37,882 - Changed @n for item 29N7RMFW from Lucas2020d to Lucas2020i.
# 2026-03-10 16:58:37,883 - Changed @n for item TCKD7Q2X from Lucas2020e to Lucas2020g.
# 2026-03-10 16:58:37,885 - Changed @n for item 7HHPF3H6 from Lucas2020a to Lucas2020e.
# 2026-03-10 16:58:37,886 - Changed @n for item 6HSTLS5K from Lucas2020b to Lucas2020x.
# 2026-03-10 16:58:37,888 - Changed @n for item E67YDJ75 from Lucas2020c to Lucas2020d.
# 2026-03-10 16:58:37,889 - Changed @n for item 8VX9XW4J from Lucas2020d to Lucas2020c.
# 2026-03-10 16:58:37,890 - Changed @n for item WVA7EEN3 from Lucas2020e to Lucas2020b.
# 2026-03-10 16:58:37,891 - Changed @n for item 8JHFUQHG from Lucas2020f to Lucas2020y.
# 2026-03-10 16:58:37,892 - Changed @n for item 8S6CKNYY from Lucas2020g to Lucas2020t.
# 2026-03-10 16:58:37,894 - Changed @n for item Q79J6YVP from Lucas2020h to Lucas2020z.
# 2026-03-10 16:58:37,896 - Changed @n for item QQFL9TGH from Lucas2020i to Lucas2020s.
# 2026-03-10 16:58:37,898 - Changed @n for item CEJKVIKV from Lucas2020j to Lucas2020r.
# 2026-03-10 16:58:37,900 - Changed @n for item 52EWDFAY from Lucas2020k to Lucas2020q.
# 2026-03-10 16:58:37,901 - Changed @n for item 74UAJUUY from Lucas2020l to Lucas2020p.
# 2026-03-10 16:58:37,902 - Changed @n for item U42ET8YG from Lucas2020m to Lucas2020o.
# 2026-03-10 16:58:37,902 - Changed @n for item XH3FTLXM from Lucas2020n to Lucas2020v.
# 2026-03-10 16:58:37,904 - Changed @n for item D9HJLNZM from Lucas2020o to Lucas2020w.
# 2026-03-10 16:58:37,905 - Changed @n for item U7XA9ZTU from Ritt-Benmimoun2020 to Ritt-Benmimoun2020a.
# 2026-03-10 16:58:37,908 - Changed @n for item LLVEM62K from Hoigilt2017a to Hoigilt2017j.
# 2026-03-10 16:58:37,909 - Changed @n for item 4XXYWKMB from Hoigilt2017b to Hoigilt2017k.
# 2026-03-10 16:58:37,910 - Changed @n for item REGEWKEN from Bassiouney2020a to Bassiouney2020g.
# 2026-03-10 16:58:37,911 - Changed @n for item V3K9NNMT from Bassiouney2020b to Bassiouney2020e.
# 2026-03-10 16:58:37,912 - Changed @n for item S37ENQSM from Bassiouney2020c to Bassiouney2020d.
# 2026-03-10 16:58:37,913 - Changed @n for item JRFMMP9F from Khalfaoui2019a to Khalfaoui2019i.
# 2026-03-10 16:58:37,914 - Changed @n for item BZDLIILE from Sedighi2018 to Sedighi2018d.
# 2026-03-10 16:58:37,915 - Changed @n for item 93TTZQL9 from Vanhove2002 to Vanhove2002b.
# 2026-03-10 16:58:37,916 - Changed @n for item 73V9CH52 from Leitner2021 to Leitner2021d.
# 2026-03-10 16:58:37,917 - Changed @n for item PMXACLNH from Wilmsen1999 to Wilmsen1999a.
# 2026-03-10 16:58:37,918 - Changed @n for item JULBFCQR from Aldrich2020 to Aldrich2020b.
# 2026-03-10 16:58:37,921 - Changed @n for item 66TTKFAC from Manfredi2018a to Manfredi2018b.
# 2026-03-10 16:58:37,924 - Changed @n for item MDN3C4TX from Khalfaoui2019b to Khalfaoui2019h.
# 2026-03-10 16:58:37,926 - Changed @n for item FN7CGGBR from La_Rosa2019 to La_Rosa2019a.
# 2026-03-10 16:58:37,927 - Changed @n for item HTDXH5EU from Manfredi2018b to Manfredi2018c.
# 2026-03-10 16:58:37,929 - Changed @n for item 68NPCP4P from Hassan2021 to Hassan2021b.
# 2026-03-10 16:58:37,930 - Changed @n for item FPKIY7Y5 from Magidow2013 to Magidow2013a.
# 2026-03-10 16:58:37,932 - Changed @n for item ATRTW6ZN from Behnstedt2001 to Behnstedt2001a.
# 2026-03-10 16:58:37,933 - Changed @n for item MJXALQJE from Seeger2013 to Seeger2013d.
# 2026-03-10 16:58:37,934 - Changed @n for item GLSKPI6M from Weninger2011 to Weninger2011b.
# 2026-03-10 16:58:37,935 - Changed @n for item 9AW5782P from Behnstedt2011a to Behnstedt2011b.
# 2026-03-10 16:58:37,936 - Changed @n for item RSHQSSRN from Caubet2008 to Caubet2008b.
# 2026-03-10 16:58:37,938 - Changed @n for item 3EM6WR35 from Turner2021 to Turner2021a.
# 2026-03-10 16:58:37,941 - Changed @n for item CG324JCW from Behnstedt2011b to Behnstedt2011a.
# 2026-03-10 16:58:37,942 - Changed @n for item T5RZ7BGS from Havelová2000 to Havelová2000a.
# 2026-03-10 16:58:37,943 - Changed @n for item C62HQCCX from Souag2016 to Souag2016a.
# 2026-03-10 16:58:37,944 - Changed @n for item P65WR4C7 from Hachimi2007 to Hachimi2007b.
# 2026-03-10 16:58:37,945 - Changed @n for item RXVPJ3LT from Lagerqvist2020 to Lagerqvist2020b.
# 2026-03-10 16:58:37,946 - Changed @n for item 8BS3JNRN from Camilleria to Camilleric.
# 2026-03-10 16:58:37,947 - Changed @n for item 7GK25787 from Camilleric to Camilleria.
# 2026-03-10 16:58:37,949 - Changed @n for item V5S29A2N from Manfredi2017 to Manfredi2017a.
# 2026-03-10 16:58:37,950 - Changed @n for item GN9Z48YQ from Khalfaoui2019a to Khalfaoui2019b.
# 2026-03-10 16:58:37,951 - Changed @n for item UQYJSQT7 from Khalfaoui2019b to Khalfaoui2019a.
# 2026-03-10 16:58:37,952 - Changed @n for item AGKRXVK9 from Ouali2017 to Ouali2017a.
# 2026-03-10 16:58:37,953 - Changed @n for item Z9R6HIG2 from Haddad2016 to Haddad2016a.
# 2026-03-10 16:58:37,954 - Changed @n for item 9D8AWSBR from Miller2019 to Miller2019a.
# 2026-03-10 16:58:37,955 - Changed @n for item 5ZSVFVJP from Holes2010 to Holes2010a.
# 2026-03-10 16:58:37,957 - Changed @n for item 8ET3UBZD from Holes2004 to Holes2004a.
# 2026-03-10 16:58:37,958 - Changed @n for item QSU9K5J9 from Rosenhouse2001 to Rosenhouse2001a.
# 2026-03-10 16:58:37,959 - Changed @n for item SHYQITM2 from Bidaoui2020 to Bidaoui2020a.
# 2026-03-10 16:58:37,961 - Changed @n for item J4CFIKM4 from Hary1996 to Hary1996a.
# 2026-03-10 16:58:37,962 - Changed @n for item KBTFRP8Z from Palva1991 to Palva1991a.
# 2026-03-10 16:58:37,964 - Changed @n for item 3MB7YTPC from Rosenhouse2000 to Rosenhouse2000b.
# 2026-03-10 16:58:37,965 - Changed @n for item UKTLGGAF from Rosenhouse2004 to Rosenhouse2004b.
# 2026-03-10 16:58:37,966 - Changed @n for item 5VR4DBB7 from Procházka2021 to Procházka2021c.
# 2026-03-10 16:58:37,967 - Changed @n for item YP9BHNB3 from Behnstedt2013 to Behnstedt2013b.
# 2026-03-10 16:58:37,968 - Changed @n for item DBZLPYE5 from Behnstedt1985 to Behnstedt1985d.
# 2026-03-10 16:58:37,970 - Changed @n for item 8MCWHHQP from Behnstedt2016 to Behnstedt2016a.
# 2026-03-10 16:58:37,971 - Changed @n for item VGRC9CGS from Abu_Guba2020 to Abu_Guba2020a.
# 2026-03-10 16:58:37,973 - Changed @n for item CX5B75P4 from Leitner2020 to Leitner2020a.
# 2026-03-10 16:58:37,974 - Changed @n for item 8424PHAX from Leitner2021 to Leitner2021a.
# 2026-03-10 16:58:37,976 - Changed @n for item PESWZ8F5 from Germanos2015 to Germanos2015a.
# 2026-03-10 16:58:37,977 - Changed @n for item KGQ4F4LT from Owens2013a to Owens2013c.
# 2026-03-10 16:58:37,978 - Changed @n for item KR9JCP7Z from Owens2013b to Owens2013a.
# 2026-03-10 16:58:37,979 - Changed @n for item Y6ZENW65 from Bettega2019 to Bettega2019c.
# 2026-03-10 16:58:37,980 - Changed @n for item EJHER4KP from Ould_Mohamed_Baba2007 to Ould_Mohamed_Baba2007a.
# 2026-03-10 16:58:37,982 - Changed @n for item JCG328II from Mion2017 to Mion2017b.
# 2026-03-10 16:58:37,983 - Changed @n for item BBS6VIU8 from Dallaji2017 to Dallaji2017c.
# 2026-03-10 16:58:37,984 - Changed @n for item 98DTI925 from Ritt-Benmimoun2014 to Ritt-Benmimoun2014a.
# 2026-03-10 16:58:37,985 - Changed @n for item 74TT26XU from Haig2018 to Haig2018d.
# 2026-03-10 16:58:37,986 - Changed @n for item GA588AQ8 from Palva2008 to Palva2008b.
# 2026-03-10 16:58:37,987 - Changed @n for item XETHE8AN from Al-Wer2019 to Al-Wer2019a.
# 2026-03-10 16:58:37,988 - Changed @n for item NEFKTUN8 from Jastrow1996 to Jastrow1996a.
# 2026-03-10 16:58:37,990 - Changed @n for item ZTZRV4UF from Holes2004a to Holes2004d.
# 2026-03-10 16:58:37,991 - Changed @n for item J6JKKFQ8 from Holes2004b to Holes2004e.
# 2026-03-10 16:58:37,992 - Changed @n for item UVBEGMSY from Jastrow2004 to Jastrow2004d.
# 2026-03-10 16:58:37,995 - Changed @n for item NP6VTHNH from Iraqui-Sinaceur1994 to Iraqui-Sinaceur1994b.
# 2026-03-10 16:58:37,996 - Changed @n for item SRFWYVSI from Jastrow1978 to Jastrow1978b.
# 2026-03-10 16:58:37,999 - Changed @n for item 38YG554Q from Behnstedt1999 to Behnstedt1999c.
# 2026-03-10 16:58:38,001 - Changed @n for item 4BXRMASY from Colin1931 to Colin1931c.
# 2026-03-10 16:58:38,003 - Changed @n for item DJXKPUNA from Blanc1964 to Blanc1964b.
# 2026-03-10 16:58:38,005 - Changed @n for item T2VUE8UP from Socin1894 to Socin1894b.
# 2026-03-10 16:58:38,009 - Changed @n for item GIPEKXGB from Caubet1989 to Caubet1989c.
# 2026-03-10 16:58:38,011 - Changed @n for item B5GN6L5F from Procházka2012 to Procházka2012b.
# 2026-03-10 16:58:38,013 - Changed @n for item 7Z6BC68R from Caubet1995 to Caubet1995b.
# 2026-03-10 16:58:38,016 - Changed @n for item SCFZJKRJ from Caubet1994 to Caubet1994d.
# 2026-03-10 16:58:38,017 - Changed @n for item CWNRJ8RV from Jastrow2005 to Jastrow2005c.
# 2026-03-10 16:58:38,018 - Changed @n for item E3T3HBCD from Aguadé1995 to Aguadé1995b.
# 2026-03-10 16:58:38,020 - Changed @n for item 8NKI26ZJ from Aldoukhi2014a to Aldoukhi2014b.
# 2026-03-10 16:58:38,021 - Changed @n for item UQFFZHKY from Procházka2002 to Procházka2002c.
# 2026-03-10 16:58:38,023 - Changed @n for item H72MVSDZ from Ritt-Benmimoun2005 to Ritt-Benmimoun2005a.
# 2026-03-10 16:58:38,025 - Changed @n for item 5B39ULWN from Ould_Mohamed_Baba2014 to Ould_Mohamed_Baba2014a.
# 2026-03-10 16:58:38,027 - Changed @n for item XVYQY9QS from Procházka2000 to Procházka2000a.
# 2026-03-10 16:58:38,029 - Changed @n for item 6J6XCA4K from Behnstedt1993 to Behnstedt1993a.
# 2026-03-10 16:58:38,030 - Changed @n for item G8RSG37P from Aldoukhi2014b to Aldoukhi2014a.
# 2026-03-10 16:58:38,031 - Changed @n for item FBQBMSWI from Havelová2000 to Havelová2000b.
# 2026-03-10 16:58:38,032 - Changed @n for item WMBPXL55 from Behnstedt1992 to Behnstedt1992a.
# 2026-03-10 16:58:38,034 - Changed @n for item DFAEW2X9 from Seeger2009 to Seeger2009c.
# 2026-03-10 16:58:38,035 - Changed @n for item 5FRYMT9U from Vanhove1993 to Vanhove1993b.
# 2026-03-10 16:58:38,037 - Changed @n for item YJ4MHJ23 from Mejri2006 to Mejri2006b.
# 2026-03-10 16:58:38,039 - Changed @n for item 6EM4FEVU from Procházka2004 to Procházka2004b.
# 2026-03-10 16:58:38,040 - Changed @n for item VSLPCQ6V from Behnstedt1999 to Behnstedt1999a.
# 2026-03-10 16:58:38,988 - TEI export done.

# %% [markdown]
# ## Fix TEI export
#
# Zotero's TEI serialization has some structural errors (elements in wrong position etc.) which we fix witha small XSLT transformation.

# %%
with saxonche.PySaxonProcessor(license=False) as proc:
# SaxonC 1.2.1 Python has many known bugs but isn't maintained anymore
# Many of the documented API specs are not working
    print(proc.version)
    proc.set_cwd(os.path.dirname(os.path.abspath('')))
    print(proc.cwd)

def transform(source, xsl, output, parameters=[]):
    try:
        with saxonche.PySaxonProcessor(license=False) as proc:
            proc.set_configuration_property("xi", "on")
            saxon = proc.new_xslt30_processor()
            for param in parameters:
                saxon.set_parameter(name=param, value=proc.make_string_value(parameters[param]))
            exec = saxon.compile_stylesheet(stylesheet_file=os.path.abspath(xsl))
            exec.apply_templates_returning_file(source_file=os.path.abspath(source), output_file=os.path.abspath(output))
            if exec.exception_occurred:
                print(saxon.get_error_message())
                print(f"Transformation failed: {source} with stylesheet {xsl} -> {output}")
            if os.path.exists(os.path.abspath(output)):
                return output
            else:
                print(f"Error transforming {source} with stylesheet {xsl}")
    except Exception as e:
        print(f"An error occurred: {e}")

def applyTransformation(pathToZoteroExport, xslPath, pathToOutput=None):
    if pathToOutput is None:
        pathToOutput = pathToZoteroExport + ".tmp"
    transform(pathToZoteroExport, xslPath, pathToOutput)
    return pathToOutput

# fix Zotero export
pathToFixZoteroXSL="../../082_scripts_xsl/fix_zotero_TEI_export.xsl"
applyTransformation(pathToZoteroExport, pathToFixZoteroXSL, pathToZoteroExport)

# add decade of data collection
pathToDOCXSL = "../../082_scripts_xsl/tei_2_tei_zotero_doc.xsl"
applyTransformation(pathToZoteroExport, pathToDOCXSL, pathToZoteroExport)
# Out:
# SaxonC-HE 12.9 from Saxonica
# Q:\basexwibarab\featuredb\080_scripts_generic
# '../../010_manannot/vicav_biblio_tei_zotero.xml'

# %%
def validate(path, rngSchema):
    """Validate a document against the rngSchema. Returns a list of dicts of which each one represents a validation (or parsing) error."""
    validationErrors = []
    
    try:
        doc = etree.parse(path)
    
        # relaxng validation
        relaxng_doc = etree.parse(rngSchema)
        relaxng = etree.RelaxNG(relaxng_doc)
        relaxng.assertValid(doc)
        
    
    except etree.XMLSyntaxError as e:
        valErrObj = {
            "type" : "error",
            "message": str(e), 
            "line": e.lineno,
            "source": path, 
            "location": "n/a",
            "stage" : "parsing", 
            "exceptionType": type(e).__name__
        }
        
        validationErrors.append(valErrObj)     
        return validationErrors
        
    except etree.DocumentInvalid as e:
        for error in e.error_log:
            # we ignore rng errors about @schemaLocation since 
            # that is needed for validation in the TEI-enricher
            if error.message != "Invalid attribute schemaLocation for element TEI":
                location = "n/a" if error.path is None else error.path
                valErrObj = {
                    "type" : "error",
                    "message": error.message, 
                    "line": error.line, 
                    "source": path, 
                    "location": location,
                    "stage" : "relaxng", 
                    "exceptionType": type(e).__name__
                }
                # DEBUG
                print(valErrObj)
                validationErrors.append(valErrObj)        
    
    return validationErrors

# %% [markdown]
# ## report duplicate xml:ids
#
# Since bibl-ids are entered manually, they might contain duplicate. We report them here.

# %%
zoteroExport = ET.parse(pathToZoteroExport)
ids=[]
bibls=zoteroExport.findall('.//biblStruct', xmlns)
for bibl in bibls:
    id = bibl.get("{http://www.w3.org/XML/1998/namespace}id")
    url = bibl.get("corresp")
    ids.append((id,url))

ids.sort(key=lambda x: x[0])
groups=[]
for key, group in itertools.groupby(ids, lambda x: x[0]):
    groups.append((key, [i[1] for i in list(group)]))

for i in groups:
    if len(i[1]) > 1:
        print(i[0]+": "+str(len(i[1]))+" entries with this id: "+", ".join(i[1]))

# %% [markdown]
# ## Validate Zotero Export against TEI all

# %%
tei_all = "../../803_RNG_Schematron/tei_all.rng"
errors=validate(pathToZoteroExport, tei_all)
if not errors:
    print("Zotero export is valid!")
else:
    errors

# %% [markdown]
# ## Slow but validating code
#
# The following code fetches items Zotero unique id by Zotero unique id. This is much slower but could potentially find missing items.

# %% [raw]
# errors = []
# max_fetch = limit_downloads_to if limit_downloads_to is not None else len(item_ids)
# logging.info("Fetching at most " + str(max_fetch) + " TEI/XML.")
# async def get_item_tei_from_group(item_id, session):
#     bibl_struct = await get_item_tei(group_id, item_id, session)
#     if bibl_struct:
#         list_bibl.append(bibl_struct)
#     else:
#         logging.debug("Can not append " + item_id)
#         errors.append(item_id)
#
# async def async_download():
#     conn = aiohttp.TCPConnector(limit=conn_limit)
#     timeout = aiohttp.ClientTimeout(total=total_timeout)
#     async with aiohttp.ClientSession(connector=conn, timeout=timeout) as session:
#         await asyncio.gather(*[get_item_tei_from_group(item_id, session) for item_id in item_ids[:max_fetch]])
#
# asyncio.run(async_download())
#
# list_bibl[:] = sorted(list_bibl, key=lambda child: child.get("{http://www.w3.org/XML/1998/namespace}id"))
# with open('../../010_manannot/vicav_biblio_tei_zotero.xml', 'wb') as f:
#     ET.indent(template)
#     template.write(f, encoding='utf-8',xml_declaration=True)
#     logging.info("TEI export done.")
#
# # Export IDs of items with errors
# with open("errors.json","w", encoding = "utf-8") as f:
#     json.dump(errors, f)
#     logging.info("Exported errors.json.")
